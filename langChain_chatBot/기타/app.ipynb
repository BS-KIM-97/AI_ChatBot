# %% [markdown]
# ## 환경 설정

# %% [markdown]
# ### Modules

# %%
import os
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain_experimental.tools import PythonAstREPLTool
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.runnables import RunnablePassthrough
from Modules import logging
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.output_parsers import StrOutputParser
import pandas as pd
from langchain_community.document_loaders.csv_loader import CSVLoader
from Modules.messages import display_message_tree

# %% [markdown]
# ### DATA_PATH

# %%
DATA_PATH = "data/"

# %% [markdown]
# ### Logging

# %%
logging.langsmith("Search for documents")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# Search for documents

# %% [markdown]
# ## 1. Lead_Data

# %%
loader = CSVLoader(
    file_path = DATA_PATH + "qna.csv", 
    encoding="utf-8",
    csv_args={
        "delimiter": ",",
        "quotechar": '"',
        "fieldnames":[
            "question_title",
            "accepted_answer_body",
        ],
    },
)

# %%
docs = loader.load()

# %%
# print(data[1].page_content)

# %%
for doc in docs:
    print(doc.metadata)

# %%
type(docs)
# Out:
# list

# %% [markdown]
# ## 2. Text Split

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=80)

# %%
split_docs= text_splitter.split_documents(docs)

# %% [markdown]
# ## 3. Vector DB

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()  # 사용 중인 임베딩 모델에 따라 설정
vector_store = FAISS.from_documents(split_docs, embeddings)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12920\999770028.py:4: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()  # 사용 중인 임베딩 모델에 따라 설정

# %%
vector_store.docstore.__dict__
# Out:
# {'_dict': {'36a71fcd-c1db-4b4a-89cf-f7dbbe2329df': Document(metadata={'source': 'data/qna.csv', 'row': 0}, page_content='question_title: question_title\naccepted_answer_body: accepted_answer_body'),
#   '33db2ce7-ca36-4327-af2c-a270a996c601': Document(metadata={'source': 'data/qna.csv', 'row': 1}, page_content='question_title: @roo_validator error when importing langchain.text_splitter Python\naccepted_answer_body: <p>I was using LangChain 0.0.20 and I got the same issue. Upgrading to Python 3.9 and LangChain 0.0.224 fixed this issue for me.</p>'),
#   '62c8cbcb-cd83-4a4f-a5db-7e6805cc7069': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='question_title: Any way to check if a number is already within a 3x3 grid in a 9x9 grid of nested lists?\naccepted_answer_body: <p>First you just need a given cell (row,col) which is the top left corner (the start) of the 3x3 subgrid you are trying to check:</p>\n<pre><code>start_row = (row // 3) * 3'),
#   '11554a89-53d4-41fd-a500-4ab251a384fd': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='<pre><code>start_row = (row // 3) * 3\nstart_col = (col // 3) * 3\n</code></pre>\n<p>Then simply iterate through the 3x3 subgrid.</p>\n<p><strong>Function implementation</strong>:</p>\n<pre><code>def is_valid_move(board, row, col, num):\n    # Check row and column'),
#   '4a88a6d8-fe65-40b7-a38d-31ce63c63b9e': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='<pre><code>def is_valid_move(board, row, col, num):\n    # Check row and column\n    if num in board[row] or any(board[i][col] == num for i in range(9)):\n        return False\n    \n    # Determine the top-left corner of the 3x3 subgrid\n    start_row, start_col = 3 * (row // 3), 3 * (col // 3)'),
#   '0b154506-6614-49ba-a92a-4227c57ca9be': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='start_row, start_col = 3 * (row // 3), 3 * (col // 3)\n    \n    # Check the 3x3 subgrid\n    for r in range(start_row, start_row + 3):\n        if num in board[r][start_col:start_col + 3]:\n            return False\n    return True\n</code></pre>\n<p>Add this:</p>\n<pre><code># Main Game Loop'),
#   'fc8df0ae-b616-451d-a816-0c2d3a53e47d': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='return True\n</code></pre>\n<p>Add this:</p>\n<pre><code># Main Game Loop\nwhile True:'),
#   'fd08ee6e-5fbd-4fcb-8bbb-ba34d2f3c729': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='...\n        if is_valid_move(board, row, col, num):\n            board[row][col] = num\n            print(f&quot;Placed {num} at ({row}, {col}).&quot;)\n        else:\n            print(&quot;Invalid move. Number conflicts with existing ones.&quot;)\n        \n...\n</code></pre>'),
#   '4c5906f0-c7fa-4222-a704-788a3ad7822b': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='...\n</code></pre>\n<p><strong>Non Function implementation</strong> (requested in comment as additional requirement)</p>\n<p>Instead of adding a function you can just add the same logic into the main loop iteself.</p>\n<pre><code>        # Subgrid Check\n        start_row = (rowchoice // 3) * 3'),
#   'eea4fd52-61ad-42ea-ba9c-319f9cfd2a4f': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='<pre><code>        # Subgrid Check\n        start_row = (rowchoice // 3) * 3\n        start_col = (columnchoice // 3) * 3\n        subgrid_valid = True\n        for r in range(start_row, start_row + 3):\n            for c in range(start_col, start_col + 3):\n                if board[r][c] == guess:'),
#   '0c6fbcb5-176a-4f06-bd69-f15e0cd81878': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='if board[r][c] == guess:\n                    subgrid_valid = False\n                    break\n            if not subgrid_valid:\n                break\n        if not subgrid_valid:\n            print(&quot;Number  already exists in the 3x3 subgrid.&quot;)\n            continue'),
#   '4f9c827c-2dc5-4bb8-9306-f32d80d2b037': Document(metadata={'source': 'data/qna.csv', 'row': 2}, page_content='</code></pre>'),
#   'b41a94cd-23f3-49f6-befc-4bd5c119f826': Document(metadata={'source': 'data/qna.csv', 'row': 3}, page_content='question_title: Type hint for a tuple of variable length (variadic tuple)?\naccepted_answer_body: <p>We can annotate variable-length homogeneous tuples using the <code>...</code> literal (aka <code>Ellipsis</code>) like this:</p>'),
#   '51372f72-0681-426c-91ea-38a2ffe613ef': Document(metadata={'source': 'data/qna.csv', 'row': 3}, page_content='<pre class="lang-py prettyprint-override"><code>def process_tuple(t: Tuple[str, ...]):\n    ...\n</code></pre>\n<p>or for <strong>Python3.9+</strong></p>\n<pre class="lang-py prettyprint-override"><code>def process_tuple(t: tuple[str, ...]):\n    ...\n</code></pre>'),
#   'a0a55c59-2f09-4c6a-ae0b-b4e9acfe9a8e': Document(metadata={'source': 'data/qna.csv', 'row': 3}, page_content='...\n</code></pre>\n<p>After that, the errors should go away.</p>\n<p>From the <a href="https://docs.python.org/3/library/typing.html#typing.Tuple" rel="nofollow noreferrer">docs</a>:</p>\n<blockquote>\n<p>To specify a variable-length tuple of homogeneous type, use literal'),
#   'c9bdf2e7-5744-48ce-9492-03b37e62bcce': Document(metadata={'source': 'data/qna.csv', 'row': 3}, page_content='<p>To specify a variable-length tuple of homogeneous type, use literal\nellipsis, e.g. <code>Tuple[int, ...]</code>. A plain <code>Tuple</code> is equivalent to\n<code>Tuple[Any, ...]</code>, and in turn to <code>tuple</code>.</p>\n</blockquote>'),
#   '85d1158d-a67b-4333-9b2b-6735a2cc424e': Document(metadata={'source': 'data/qna.csv', 'row': 3}, page_content='</blockquote>\n<p>More info about annotating <code>tuple</code>s can be found at <a href="https://docs.python.org/3/library/typing.html#annotating-tuples" rel="nofollow noreferrer">&quot;Annotating tuples&quot; section of the docs</a>.</p>'),
#   '30932a60-7958-489a-af02-0bac8e566d40': Document(metadata={'source': 'data/qna.csv', 'row': 4}, page_content="question_title: How can I do one-hot encoding from multiple columns\naccepted_answer_body: <p>Use melt and crosstab.</p>\n<pre><code>tmp = df.melt('Item')\nresult = pd.crosstab(tmp['Item'], tmp['value']).reset_index().rename_axis(None, axis=1)"),
#   'f63fe398-dd4d-4a2f-8168-1577216fc0a9': Document(metadata={'source': 'data/qna.csv', 'row': 4}, page_content='Item  1  2  3  4  5  6  7  8  9\n0  Item1  1  1  0  1  0  0  0  1  0\n1  Item2  0  1  1  0  0  1  1  0  0\n2  Item3  0  0  0  1  1  0  1  0  1\n3  Item4  1  0  0  0  1  1  1  0  0\n4  Item5  0  0  1  1  0  0  1  1  0\n</code></pre>'),
#   'bb35783c-6560-47d0-b13a-51818b492135': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content="question_title: What is the difference between TypeVar and NewType?\naccepted_answer_body: <p>The two concepts aren't related any more than any other type-related concepts.</p>"),
#   'e6282f1a-efc4-49b8-980c-e2d95b7940c2': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<p>In short, a <code>TypeVar</code> is a variable you can use in type signatures so you can refer to the same unspecified type more than once, while a <code>NewType</code> is used to tell the type checker that some values should be treated as their own type.</p>'),
#   '291d4e6f-5654-4ab9-89f2-c9596fa23b1e': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<h1><a href="https://docs.python.org/3/library/typing.html#typing.TypeVar" rel="nofollow noreferrer">Type Variables</a></h1>\n<p>To simplify, type variables let you refer to the same type more than once without specifying exactly which type it is.</p>'),
#   '8ce0fbde-888d-491b-9c58-1082af5eb994': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content="<p>In a definition, a single type variable always takes the same value.</p>\n<pre><code># (This code will type check, but it won't run.)\nfrom typing import TypeVar, Generic"),
#   '0101a9bc-8068-4cb0-b51d-4e3d1478ab02': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content="# Two type variables, named T and R\nT = TypeVar('T')\nR = TypeVar('R')\n\n# Put in a list of Ts and get out one T\ndef get_one(x: list[T]) -&gt; T: ...\n\n# Put in a T and an R, get back an R and a T\ndef swap(x: T, y: R) -&gt; tuple[R, T]:\n    return y, x"),
#   '986db389-3829-405d-9d7f-4e6ddc580211': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='# A simple generic class that holds a value of type T\nclass ValueHolder(Generic[T]):\n    def __init__(self, value: T):\n        self.value = value\n    def get(self) -&gt; T:\n        return self.value'),
#   '80a9d4a3-1514-4f48-86a6-75d78165bd15': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content="x: ValueHolder[int] = ValueHolder(123)\ny: ValueHolder[str] = ValueHolder('abc')\n</code></pre>\n<p>Without type variables, there wouldn't be a good way to declare the type of <code>get_one</code> or <code>ValueHolder.get</code>.</p>"),
#   'ee19d2aa-3a44-4aa5-87ea-d64c0cc82ea2': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<p>There are a few other options on <code>TypeVar</code>. You can restrict the possible values by passing in more types (e.g. <code>TypeVar(name, int, str)</code>), or you can give an upper bound so every value of the type variable must be a subtype of that type (e.g. <code>TypeVar(name,'),
#   'b50143b8-e259-4178-b385-8da8706a5efa': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='of the type variable must be a subtype of that type (e.g. <code>TypeVar(name, bound=int)</code>).</p>'),
#   '570c18bd-8047-4b11-8c41-743b433f3362': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<p>Additionally, you can decide whether a type variable is covariant, contravariant, or neither when you declare it. This essentially decides when subclasses or superclasses can be used in place of a generic type. <a href="https://www.python.org/dev/peps/pep-0484/#covariance-and-contravariance"'),
#   '0af56541-28ed-4d5d-a8db-f07af41ef0f9': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='href="https://www.python.org/dev/peps/pep-0484/#covariance-and-contravariance" rel="nofollow noreferrer">PEP 484 describes these concepts</a> in more detail, and refers to additional resources.</p>'),
#   'a5dcb2d6-8f48-4303-9a56-c2ad0b3f9522': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<h2>Addendum: Python 3.12 generic parameter lists</h2>'),
#   '9f3b423e-f6e8-4039-963d-3d419f4c83fa': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<p>Starting in Python 3.12, the following syntax has been available to declare type variables.</p>\n<pre><code>def get_one[T](x: list[T]) -&gt; T: ...\n\ndef swap[T, R](x: T, y: R) -&gt; tuple[R, T]: ...'),
#   '7ba31c7d-5225-4a2a-afaa-9d45fa24cabd': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='class ValueHolder[T]:\n    def __init__(self, value: T): ...\n    def get(self) -&gt; T: ...\n</code></pre>'),
#   '3fc00240-c100-4561-9c5f-68e00f9317c3': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<p>These declarations are equivalent to those above, but now the type variables are only defined in type signatures within their functions/classes, rather than being stored in regular Python variables. The Python 3.12 release notes contain <a'),
#   '01ce7569-1811-41d9-90f7-5866b6dd0ee2': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='stored in regular Python variables. The Python 3.12 release notes contain <a href="https://docs.python.org/3/whatsnew/3.12.html#whatsnew312-pep695" rel="nofollow noreferrer">a summary</a>, as well as links to <a href="https://docs.python.org/3/reference/compound_stmts.html#type-params"'),
#   '274ba112-8ec3-49a8-88dd-f2a3ceee7971': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<a href="https://docs.python.org/3/reference/compound_stmts.html#type-params" rel="nofollow noreferrer">more-detailed documentation</a>.</p>'),
#   '830d3c5b-b772-4cf0-b68e-b05813ea5a7c': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<h1><a href="https://docs.python.org/3/library/typing.html#newtype" rel="nofollow noreferrer">NewType</a></h1>'),
#   'f7be6d67-db03-4c3a-81f3-0790e3098055': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<p>A <code>NewType</code> is for when you want to declare a distinct type without actually doing the work of creating a new type or worry about the overhead of creating new class instances.</p>'),
#   'a1532f73-1913-4f8e-a234-15edcf90f6ca': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content="<p>In the type checker, <code>NewType('Name', int)</code> creates a subclass of <code>int</code> named &quot;Name.&quot;</p>\n<p>At runtime, <code>NewType('Name', int)</code> is not a class at all; it is actually the identity function, so <code>x is NewType('Name', int)(x)</code> is always true.</p>"),
#   'f346a73c-0dfd-4868-a9d1-cc8f9b5009e9': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<pre><code>from typing import NewType'),
#   '22b554d2-05a7-4852-a11b-1c7f914fd445': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content="UserId = NewType('UserId', int)\n\ndef get_user(x: UserId): ...\n\nget_user(UserId(123456)) # this is fine\nget_user(123456) # that's an int, not a UserId"),
#   '257c87c0-3352-48d8-ab89-69f2173085aa': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='UserId(123456) + 123456 # fine, because UserId is a subclass of int\n</code></pre>\n<p>To the type checker, <code>UserId</code> looks something like this:</p>\n<pre><code>class UserId(int): pass\n</code></pre>\n<p>But at runtime, <code>UserId</code> is basically just this:</p>'),
#   '5d03f11b-b66b-4e7b-8f30-74fcae1ff501': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<p>But at runtime, <code>UserId</code> is basically just this:</p>\n<pre><code>def UserId(x): return x\n</code></pre>'),
#   'd3fed37f-1016-4d15-aa84-c586b5284de2': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='</code></pre>\n<p>There\'s almost nothing more than that to a <code>NewType</code> at runtime. In Python 3.8.1, its <a href="https://github.com/python/cpython/blob/v3.8.1/Lib/typing.py#L1787-L1811" rel="nofollow noreferrer">implementation</a> was almost exactly as follows:</p>'),
#   '806839ea-1ba9-4be8-8849-9db6bcb78f1c': Document(metadata={'source': 'data/qna.csv', 'row': 5}, page_content='<pre><code>def NewType(name, type_):\n    def identity(x):\n        return x\n    identity.__name__ = name\n    return identity\n</code></pre>'),
#   'e293cb58-3768-456e-88dc-65cb24ffd784': Document(metadata={'source': 'data/qna.csv', 'row': 6}, page_content='question_title: insert new line into duckdb table with a map column from python dict\naccepted_answer_body: <p>You have to add the <code>MAP</code> keyword before passing the dictionary to be inserted, like this:</p>'),
#   'a49169d6-2522-42d1-8ff5-8d8ee9fb1fe1': Document(metadata={'source': 'data/qna.csv', 'row': 6}, page_content='<pre class="lang-py prettyprint-override"><code>con.execute(&quot;INSERT INTO tbl VALUES (MAP {\'a\': \'b\'})&quot;)\n</code></pre>\n<p>For your particular case you can do this:</p>\n<pre class="lang-py prettyprint-override"><code>row = str(my_dict).replace(&quot;{&quot;, &quot;MAP {&quot;)'),
#   'c08db85d-15a5-4a7d-aae5-a2d54e25aca8': Document(metadata={'source': 'data/qna.csv', 'row': 6}, page_content="query = f&quot;INSERT INTO testtest (str_col, map_col) VALUES ('test_str', {row})&quot;\ncon.execute(query)\n</code></pre>\n<p>This should work.</p>"),
#   '27bcd29e-68f8-405b-8edf-377f3e7daa3e': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content='question_title: pyFPDF: autopagebreak causes, that only one row is per page\naccepted_answer_body: <h2>Explanation of the error</h2>'),
#   '24d95805-3c6b-454d-90b0-9b775eae2731': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content='accepted_answer_body: <h2>Explanation of the error</h2>\n<p>The problem starts at the end of the first page when the value of <code>y</code> is <em>high</em> (may be <code>y</code> value is <code>180</code> mm). At this point your code executed the instructions:</p>'),
#   '1985464e-399d-4bf4-b167-fdfe066f5a7f': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content="<pre><code>self.cell(40,15,df['LG'].iloc[i],1,ln=0,align='C')\nself.cell(40, 15, df['LGP'].iloc[i], 1, ln=0, align='C')\nself.cell(40, 15, df['ZEIT'].iloc[i], 1, ln=1, align='C')\n</code></pre>"),
#   '26e5b173-c180-49ab-afb3-b93bcd9ae218': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content="self.cell(40, 15, df['ZEIT'].iloc[i], 1, ln=1, align='C')\n</code></pre>\n<p>and inserts the last row in the first page. After that the library creates a new page and it is ready to place the next row at the start of this new page.<br />\nAt this point are executed the following 2 instructions:</p>"),
#   '9f3f1f22-350e-4471-b138-9da7f1f5a686': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content="At this point are executed the following 2 instructions:</p>\n<pre><code># here y value is 'high' (180 mm)\ny = y + 15\n# the value of y now is 195\nself.set_y(y)\n</code></pre>\n<p>The instruction <code>self.set_y(y)</code> places the code at the start of the second page.<br />"),
#   'ec433722-6204-4ac7-a7ed-4a08af0f384c': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content='Now is inserted a new row, but <code>y</code> is equal to <code>195</code> and it is yet increased by <code>15</code>. So when is executed the instruction <code>self.set_y(210)</code> the library creates the third page.</p>\n<h2>How to avoid the error</h2>'),
#   'e9db96cb-0718-4592-ab9b-fcf3a6df132b': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content='<h2>How to avoid the error</h2>\n<p>To avoid this you have to check the value of <code>self.get_y()</code> that is the current position in the page. On the other hand, <code>y</code> save the Y position in the page before the insertion of the last line of the text.'),
#   '327e0eef-d275-4e15-8144-74f12547839e': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content='If the current position becomes <code>&lt;=</code> of the value of <code>y</code> means that the PyFPDF library has automatically added a new page and it has set the Y position at the top of the new page.<br />'),
#   'e47dac4d-f6a3-45fa-84e6-934703bce63a': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content='In this case the value of <code>y</code> must not increase but it must be set equal to the current_position.</p>\n<h2>Modification to the <code>content()</code> method</h2>\n<p>One possible solution is modify your <code>content()</code> function as followed:</p>\n<pre><code>def content(self,df):'),
#   '77f76100-4d93-4cb4-8aa4-e7d0df690ed1': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content="<pre><code>def content(self,df):\n    y=30\n    for i in range(len(df)):\n        self.set_y(y)\n        self.cell(40,15,df['LG'].iloc[i],1,ln=0,align='C')\n        self.cell(40, 15, df['LGP'].iloc[i], 1, ln=0, align='C')\n        self.cell(40, 15, df['ZEIT'].iloc[i], 1, ln=1, align='C')"),
#   '28010317-cee1-4b12-b5c9-4cc21035c47e': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content="self.cell(40, 15, df['ZEIT'].iloc[i], 1, ln=1, align='C')\n        curr_y = self.get_y()\n        if curr_y &gt; y:\n            # here we are in the of the page\n            y = y + 15\n        else:\n            # here the library adds a new page so curr_y has a low value\n            y = curr_y"),
#   'e2515e84-d9eb-4cca-9611-99de37b41dc2': Document(metadata={'source': 'data/qna.csv', 'row': 7}, page_content='y = curr_y\n</code></pre>'),
#   '4467c99c-ff1a-45fa-ae45-000986234a87': Document(metadata={'source': 'data/qna.csv', 'row': 8}, page_content='question_title: redis (ledis) become slow after flushdb\naccepted_answer_body: <p>I find that change <code>mget_threshold</code> to large than the number of mget is more useful.</p>'),
#   '7d4149fd-713e-41a7-ba48-3efc8ab18f86': Document(metadata={'source': 'data/qna.csv', 'row': 9}, page_content='question_title: How to join my Telegram Bot to PUBLIC channel'),
#   'b525274d-065b-4d19-b01b-c0fac743400a': Document(metadata={'source': 'data/qna.csv', 'row': 9}, page_content='accepted_answer_body: <p>Till today, only the Channel Creator can add a bot (as Administrator or Member) to the Channel, whether public or private. Even the other Channel Administrators cannot add a normal member leave alone adding a bot, rather they can only post into the channel.'),
#   'e67981ab-8894-45af-b384-10693ff21120': Document(metadata={'source': 'data/qna.csv', 'row': 9}, page_content='As far as joining the bot via the invite link, there is yet no such method in Bot API to do so. All such claims of adding the bot to a channel by non Creator are false.</p>'),
#   'f84aa4d3-2876-45c8-8bba-4d73fa60c28e': Document(metadata={'source': 'data/qna.csv', 'row': 10}, page_content='question_title: umap.plot requires pandas matplotlib datashader bokeh holoviews scikit-image and colorcet to be installed\naccepted_answer_body: <p>The solution is as below.</p>\n<pre><code>pip install umap-learn[plot]\nimport umap.umap_ as umap\nimport umap.plot\n1st one will make a clear of error.'),
#   '8df72242-9e5a-4a7c-b8eb-442028e35d76': Document(metadata={'source': 'data/qna.csv', 'row': 10}, page_content='import umap.umap_ as umap\nimport umap.plot\n1st one will make a clear of error.\n</code></pre>\n<p>I upload self-answered question as nobody gave a solution in Stackoverflow.</p>\n<p>Hope it helps you.</p>'),
#   '05abdd16-856e-4ed4-ad8b-896759521f42': Document(metadata={'source': 'data/qna.csv', 'row': 11}, page_content='question_title: Check if string does not contain strings from the list with wildcard when % symbol in the list value'),
#   'f4f10bf2-d89e-4a35-a2f1-0161c8fa9dcd': Document(metadata={'source': 'data/qna.csv', 'row': 11}, page_content='accepted_answer_body: <p>One approach would be to use regular expressions.  In this approach, we can replace <code>%</code> in the <code>newlist</code> by <code>.*</code>.  Then, use <code>re.search</code> along with a list comprehension to find any matches.</p>'),
#   '636bf0b7-59b4-47fe-9d0e-62debc369587': Document(metadata={'source': 'data/qna.csv', 'row': 11}, page_content='<pre class="lang-py prettyprint-override"><code>newlist = [\'test\', \'%ing\', \'osh\', \'16fg\']\ntartext = \'Singing\''),
#   '2c33ab4a-dab9-43c0-b4bd-ac311cfb7440': Document(metadata={'source': 'data/qna.csv', 'row': 11}, page_content="newlist = [r'^' + x.replace('%', '.*') + r'$' for x in newlist]\nnum_matches = sum([1 for x in newlist if re.search(x, tartext)])\n\nif num_matches &gt; 0:\n    print(&quot;found a match&quot;)  # prints here\nelse:\n    print(&quot;no matches&quot;)\n</code></pre>"),
#   '47380716-71dc-4c0b-a98e-2c991238ee62': Document(metadata={'source': 'data/qna.csv', 'row': 12}, page_content='question_title: How to fix line bleeding in fpdf'),
#   '939ca1df-762c-435b-9cf4-69166790e392': Document(metadata={'source': 'data/qna.csv', 'row': 12}, page_content='accepted_answer_body: <p>This is connected to  <a href="https://stackoverflow.com/questions/38490454/generating-line-break-in-fpdf">Generating line break in FPDF</a> and the <a href="https://pyfpdf.readthedocs.io/en/latest/reference/write/index.html" rel="nofollow noreferrer">write method</a> of'),
#   '42e0a3e6-c536-440e-87a7-e11f2b86a0ec': Document(metadata={'source': 'data/qna.csv', 'row': 12}, page_content='rel="nofollow noreferrer">write method</a> of fpdf.</p>'),
#   '12fa9e70-39b9-431c-bac8-e12648c5537d': Document(metadata={'source': 'data/qna.csv', 'row': 12}, page_content='<p>As described in the <a href="https://stackoverflow.com/a/38491529/9501624">answer</a> to above mentioned question, try replacing <code>pdf.write</code> by <a href="https://pyfpdf.readthedocs.io/en/latest/reference/multi_cell/index.html" rel="nofollow noreferrer"><code>pdf.multi_cell</code></a>'),
#   '17470fd7-3d06-475a-84d7-0c2d5b105495': Document(metadata={'source': 'data/qna.csv', 'row': 12}, page_content='rel="nofollow noreferrer"><code>pdf.multi_cell</code></a> in the <code>investment_summary</code> function:</p>'),
#   '7cbc051a-eed1-4548-80bf-02810638a689': Document(metadata={'source': 'data/qna.csv', 'row': 12}, page_content='<pre class="lang-py prettyprint-override"><code>def investment_summary(pdf, text, bullet_indent=15):\n    pdf.set_font(&quot;Arial&quot;, size=8)'),
#   '1ca0d9a1-7677-4b19-a9a4-b0b3e50dfaac': Document(metadata={'source': 'data/qna.csv', 'row': 12}, page_content='for point in text.splitlines():\n        if point.startswith(&quot;-&quot;):\n            pdf.set_x(bullet_indent)\n        pdf.multi_cell(0, 5, point)\n</code></pre>'),
#   '1c27eecf-39d6-410e-82ba-7675aaf314df': Document(metadata={'source': 'data/qna.csv', 'row': 13}, page_content="question_title: Sum of value in a dictionary\naccepted_answer_body: <p>It can be</p>\n<pre><code>dic1 = {'2012-03-06':['1','4','5'],'2012-03-12':['7','3','10']} \nfor i in dic1: \n    print(i+','+ str(sum(map(int, dic1[i]))))\n</code></pre>"),
#   'ea590fe3-f247-48f1-ba31-14440b4f7230': Document(metadata={'source': 'data/qna.csv', 'row': 13}, page_content="for i in dic1: \n    print(i+','+ str(sum(map(int, dic1[i]))))\n</code></pre>\n<p>In python3, <code>map(func,iter)</code> returns an iterator(list, tuple etc.) of the results after applying the given function to each item of a given iterable</p>"),
#   '6236b7ea-cbf0-4c9e-9d93-9e20a3db1e10': Document(metadata={'source': 'data/qna.csv', 'row': 14}, page_content='question_title: PyOdbc fails to connect to a sql server instance\naccepted_answer_body: <p>OK, this seems to have resolved the issue</p>\n<pre><code>import urllib    \nconnection_string = &quot;DRIVER={SQL Server};Database=people;SERVER=gagan;UID=sa;PWD=admin1&quot;'),
#   'f4790592-28cd-4dc6-a259-3e1c1f86b377': Document(metadata={'source': 'data/qna.csv', 'row': 14}, page_content='connection_string = urllib.parse.quote_plus(connection_string) \nconnection_string = &quot;mssql+pyodbc:///?odbc_connect=%s&quot; % connection_string\n</code></pre>'),
#   'd5849481-b305-49c2-a846-34ae5a526c88': Document(metadata={'source': 'data/qna.csv', 'row': 15}, page_content='question_title: Kernel not connecting in Jupyter Lab'),
#   '3a779c42-aa5e-4ac3-a851-099ec03aabf8': Document(metadata={'source': 'data/qna.csv', 'row': 15}, page_content='accepted_answer_body: <p>It looks like you have a conflict in your <code>PYTHONPATH</code>. <code>pdb</code> attempts to import <code>code</code>, but instead of getting its module it sees your <code>/home/username/Desktop/Projects/foldername/ms-p/peroo/code.py</code> file which leads to the'),
#   'ed946dd3-1152-48ec-a130-db4befbb99e9': Document(metadata={'source': 'data/qna.csv', 'row': 15}, page_content='file which leads to the failure. Rename this file to something else, e.g. <code>mycode.py</code>. This can be a common problem, e.g. you cannot have a file named <code>statistics.py</code> because you will shadow built-in <code>statistics</code> module. This is well explained in answers to: <a'),
#   '9a3080f6-7807-4256-95cd-7980c0ed6c41': Document(metadata={'source': 'data/qna.csv', 'row': 15}, page_content='<code>statistics</code> module. This is well explained in answers to: <a href="https://stackoverflow.com/questions/36250353/importing-installed-package-from-script-raises-attributeerror-module-has-no-at">Importing installed package from script raises &quot;AttributeError: module has no'),
#   '67ab9741-095b-45d0-b34b-25cd19ae9e33': Document(metadata={'source': 'data/qna.csv', 'row': 15}, page_content='installed package from script raises &quot;AttributeError: module has no attribute&quot; or &quot;ImportError: cannot import name&quot;</a>.</p>'),
#   'b51eada2-1905-413c-baa5-47b5183a6173': Document(metadata={'source': 'data/qna.csv', 'row': 16}, page_content='question_title: String-based enum in Python\naccepted_answer_body: <p>It seems that it is enough to inherit from <code>str</code> class at the same time as <code>Enum</code>:</p>\n<pre class="lang-py prettyprint-override"><code>from enum import Enum'),
#   '25e516e9-d0fe-4aa6-9e74-527fd92d2c7d': Document(metadata={'source': 'data/qna.csv', 'row': 16}, page_content="class MyEnum(str, Enum):\n    state1 = 'state1'\n    state2 = 'state2'\n</code></pre>\n<p>The tricky part is that <strong>the order</strong> of classes in the inheritance chain <em>is important</em> as this:</p>\n<pre><code>class MyEnum(Enum, str):\n    state1 = 'state1'\n    state2 = 'state2'"),
#   '370967c3-2830-470a-8ad4-87831ee669e4': Document(metadata={'source': 'data/qna.csv', 'row': 16}, page_content="<pre><code>class MyEnum(Enum, str):\n    state1 = 'state1'\n    state2 = 'state2'\n</code></pre>\n<p>throws:</p>\n<pre><code>TypeError: new enumerations should be created as `EnumName([mixin_type, ...] [data_type,] enum_type)`\n</code></pre>"),
#   'b8280f53-64c4-4774-b0cd-ecafe50a1990': Document(metadata={'source': 'data/qna.csv', 'row': 16}, page_content="</code></pre>\n<p>With the correct class the following operations on <code>MyEnum</code> are fine:</p>\n<pre><code>print('This is the state value: ' + state)\n</code></pre>\n<hr />"),
#   '4e7c825f-b54f-48de-8c34-526316378038': Document(metadata={'source': 'data/qna.csv', 'row': 16}, page_content='</code></pre>\n<hr />\n<p>As a side note, it seems that the special inheritance trick is not needed for <a href="https://www.python.org/dev/peps/pep-0498/" rel="noreferrer">formatted strings</a> which work even for <code>Enum</code> inheritance only:</p>'),
#   '8741f72d-391b-44ea-84d8-0ca32be9bbcd': Document(metadata={'source': 'data/qna.csv', 'row': 16}, page_content="<pre><code>msg = f'This is the state value: {state}'  # works without inheriting from str\n</code></pre>"),
#   'b23516cd-05a8-40a7-8b33-617b50f34bcd': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content='question_title: What is &#39;extra&#39; in pypi dependency?\naccepted_answer_body: <p>Extras are dependencies you can install <em>in addition</em> to the regular dependencies, if you ask for them explicitly. See them as optional features.</p>'),
#   '4fc91c62-aedc-4c65-bfab-5d79af9b9563': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content="<p>You can install these with the name after the <code>==</code>, with the name of the package. For example, if you install <code>somepackage</code> and want to add the <code>bcrypt</code> optional feature, use:</p>\n<pre><code>pip install 'somepackage[bcrypt]'\n</code></pre>\n<p>or</p>"),
#   '460be370-3e99-4071-8248-a4f141a1cfe0': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content="<pre><code>pip install 'somepackage[bcrypt]'\n</code></pre>\n<p>or</p>\n<pre><code>pip install 'somepackage[argon2]'\n</code></pre>\n<p>or, to include both optional extras, separate the names with commas:</p>\n<pre><code>pip install 'somepackage[bcrypt,argon2]'\n</code></pre>"),
#   '798f8dff-54f8-42c7-9a98-6fc564f673bb': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content="<pre><code>pip install 'somepackage[bcrypt,argon2]'\n</code></pre>\n<p>although using <code>somepackage[...]</code> multiple times also works as <code>pip</code> is smart enough to know that the main package is already installed.</p>"),
#   'dfe505fe-7af5-49de-b3ad-a4bd6108b2b1': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content="<p><code>pip</code> (or whatever other package install tool) maps names listed in <code>&lt;packagename&gt;[&lt;extras_name&gt;(,...)]</code> to those entries in the <code>requires_dict</code> that use the <code>&lt;dependency_spec&gt;; extra == '&lt;extras_name&gt;'</code> format, adding on the"),
#   'c55ab9df-a963-4cd1-9141-622e06467dfb': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content="extra == '&lt;extras_name&gt;'</code> format, adding on the <code>dependency_spec</code>s to the list of things to install.</p>"),
#   '8e976773-34c1-4871-b432-c2256a2f5974': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content='<p>See <a href="https://packaging.python.org/en/latest/tutorials/installing-packages/#installing-extras" rel="nofollow noreferrer"><em>Installing Setuptools &quot;Extras&quot;</em></a> in the <em>Installing Packages</em> section of the <a href="https://packaging.python.org/" rel="nofollow'),
#   '1b432a8f-a913-4352-84c6-fd171df70afa': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content='section of the <a href="https://packaging.python.org/" rel="nofollow noreferrer"><em>Python Packaging User Guide</em></a>.</p>'),
#   'c66b2b20-cb86-495c-8490-e421afb321fc': Document(metadata={'source': 'data/qna.csv', 'row': 17}, page_content='<p>It is up to the installed package itself to detect if all the dependencies for optional extra features are installed. A common pattern is to use <code>try...except ImportError:</code> guards to test for such extra dependencies being available.</p>'),
#   'b2b869c3-30c2-4bca-b6ff-3a6ee43ce3d0': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='question_title: How to use existing login token for telegram web using selenium webdriver'),
#   'a66ed8cc-0ac6-496a-a15b-9665d01e614c': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='accepted_answer_body: <p>When you open <code>https://web.telegram.org</code> manually using <em>Firefox</em>, the <em>Default Firefox Profile</em> is used. As you login and browse through the website, the websites stores <em>Authentication Cookies</em> within your system. As the cookies gets stored'),
#   '585f01c2-f89f-4a0d-a6c4-2cf18ec4d28b': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<em>Authentication Cookies</em> within your system. As the cookies gets stored within the <em>local storage</em> of the <em>Default Firefox Profile</em> even on reopening the browsers you are automatically authenticated.</p>'),
#   'f3e69b48-0fb1-4f85-935e-59829a961e7a': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<p>But when <em>GeckoDriver</em> initiates a new web browsing session for your tests everytime a temporary new <strong>mozprofile</strong> is created while launching <em>Firefox</em> which is evident from the following log:</p>'),
#   'a1f81029-2d22-4bd8-9818-43e4a748634e': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<pre><code>mozrunner::runner   INFO    Running command: "C:\\\\Program Files\\\\Mozilla Firefox\\\\firefox.exe" "-marionette" "-profile" "C:\\\\Users\\\\ATECHM~1\\\\AppData\\\\Local\\\\Temp\\\\rust_mozprofile.fDJt0BIqNu0n"\n</code></pre>'),
#   '24db81ce-5037-4212-9e40-b02121a22f1b': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<blockquote>\n  <p>You can find a detailed discussion in <a href="https://stackoverflow.com/questions/46088442/is-it-firefox-or-geckodriver-which-creates-rust-mozprofile-directory/46089240#46089240">Is it Firefox or Geckodriver, which creates “rust_mozprofile” directory</a></p>\n</blockquote>'),
#   '6c619291-66e7-4fd1-bdd4-ac5aa28bc600': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<p>Once the <em>Test Execution</em> completes and <code>quit()</code> is invoked the temporary <strong>mozprofile</strong> is deleted in the following process:</p>'),
#   '31254c5a-b17e-447b-ac7f-52ca5ceae134': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<pre><code>webdriver::server   DEBUG   -&gt; DELETE /session/f84dbafc-4166-4a08-afd3-79b98bad1470 \ngeckodriver::marionette TRACE   -&gt; 37:[0,3,"quit",{"flags":["eForceQuit"]}]\nMarionette  TRACE   0 -&gt; [0,3,"quit",{"flags":["eForceQuit"]}]'),
#   '55c016f9-c703-4c34-85a9-b300c6a05ae9': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='Marionette  TRACE   0 -&gt; [0,3,"quit",{"flags":["eForceQuit"]}]\nMarionette  DEBUG   New connections will no longer be accepted\nMarionette  TRACE   0 &lt;- [1,3,null,{"cause":"shutdown"}]\ngeckodriver::marionette TRACE   &lt;- [1,3,null,{"cause":"shutdown"}]'),
#   '89f4edc9-5afa-413c-9f72-86d8e2f0800a': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='geckodriver::marionette TRACE   &lt;- [1,3,null,{"cause":"shutdown"}]\nwebdriver::server   DEBUG   Deleting session\ngeckodriver::marionette DEBUG   Stopping browser process\n</code></pre>'),
#   'b5209749-751c-43e8-a9a6-0581299482fa': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<p>So, when you open the same page using <a href="https://stackoverflow.com/questions/54459701/what-is-selenium-and-what-is-webdriver/54482491#54482491">Selenium</a>, <em>GeckoDriver</em> and <em>Firefox</em> the cookies which were stored within the <em>local storage</em> of the <em>Default Firefox'),
#   'f4b23a28-edef-4db6-bf4b-5099affc1553': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content="which were stored within the <em>local storage</em> of the <em>Default Firefox Profile</em> aren't accessible and hence you are redirected to the <em>Login Page</em>.</p>"),
#   'fb024357-583a-4218-823e-5a5b5a8c8be8': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<hr>\n\n<p>To store and use the cookies within the <em>local storage</em> to get authenticated automatically you need to create and use a <strong>Custom Firefox Profile</strong>.</p>'),
#   'dbb0e48f-7956-420e-82b8-da421588240d': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<blockquote>'),
#   '19611081-1105-408b-b5c5-c6d429c516e8': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='<p>Here you can find a relevant discussion on <a href="https://stackoverflow.com/questions/49356081/webdriver-firefoxprofile-is-it-possible-to-use-a-profile-without-making-a-cop/49358656#49358656">webdriver.FirefoxProfile(): Is it possible to use a profile without making a copy of it?</a></p>'),
#   '084eb25c-9106-4a04-8060-35e711c92f9d': Document(metadata={'source': 'data/qna.csv', 'row': 18}, page_content='</blockquote>'),
#   '30d097bb-f0ab-4325-97c2-b44887fae2cd': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='question_title: Firebase cloud messaging HTTP v1 send error - 400 Client Error: Bad Request for url: https://fcm.googleapis.com/v1/projects/&lt;PROJECT_ID&gt;/messages:send\naccepted_answer_body: <p>This is the way to debug the above problem.</p>\n\n<p>Use</p>'),
#   '89b40944-0adc-48d0-b689-f96aafb3e470': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='<p>Use</p>\n\n<pre><code>if r.status_code != 200:\n    print(r.text)\n    r.raise_for_status()\n</code></pre>\n\n<p>instead of</p>\n\n<pre><code>if r.status_code != 200:\n    r.raise_for_status()\n</code></pre>\n\n<p>We will get the following error</p>'),
#   '3bbef237-1ffb-49f0-a306-4dba6114d24b': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='<pre><code>{\n  "error": {\n    "code": 400,\n    "message": "Invalid value at \'message.data[0].value\' (TYPE_STRING), false\\nInvalid value at \'message.data[1].value\' (TYPE_STRING), 2",\n    "status": "INVALID_ARGUMENT",\n    "details": [\n      {'),
#   'b43468bd-50a8-4d3e-ba1d-1c3a1cd020f6': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='"status": "INVALID_ARGUMENT",\n    "details": [\n      {\n        "@type": "type.googleapis.com/google.rpc.BadRequest",\n        "fieldViolations": [\n          {\n            "field": "message.data[0].value",\n            "description": "Invalid value at \'message.data[0].value\' (TYPE_STRING), false"'),
#   '252526aa-1cf9-45cd-badc-268560611e5f': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='},\n          {\n            "field": "message.data[1].value",\n            "description": "Invalid value at \'message.data[1].value\' (TYPE_STRING), 2"\n          }\n        ]\n      }\n    ]\n  }\n}\n</code></pre>'),
#   'b9d7090b-0349-45c2-8b0d-7836a38d84c4': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='<hr>\n\n<p>Look like HTTP v1 is pretty strict on the value type (It need to be String)</p>\n\n<p>Hence, instead of using</p>'),
#   '37e93dc9-ceba-445e-8711-46575095c63d': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='<pre><code>string = \'{"message":{"token": "cSW75-6OF-w:APA91bE-E6vWucBe8rRijpDLlZGHhyfwoaLJr3R1TZEvieBM-__ZXwXlBS34kUticUN_eSbwvQGTymbmtd7sHT5U9O_v9HePyVn7jnUD9IBdoZZYSQ1CrgxXS1sz9wjAd5pKHIddoKj8", "data": {"sync": false, "sync_device_count": 2}, "fcm_options": {"analytics_label":'),
#   '97123fd6-9865-47f3-923f-f5f4c008ac9f': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='{"sync": false, "sync_device_count": 2}, "fcm_options": {"analytics_label": "wenote_analytics_label"}}}\''),
#   '91fe0432-63f5-47d7-8a3b-493633fd5e15': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='</code></pre>'),
#   'f08bb506-1d57-47b1-8312-c55ceef3bebd': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='<p>We need to use</p>'),
#   '8d105ab7-4278-4328-8b5c-b0db551f83bd': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='<pre><code>string = \'{"message":{"token": "cSW75-6OF-w:APA91bE-E6vWucBe8rRijpDLlZGHhyfwoaLJr3R1TZEvieBM-__ZXwXlBS34kUticUN_eSbwvQGTymbmtd7sHT5U9O_v9HePyVn7jnUD9IBdoZZYSQ1CrgxXS1sz9wjAd5pKHIddoKj8", "data": {"sync": "false", "sync_device_count": "2"}, "fcm_options": {"analytics_label":'),
#   'fc093bd1-3dae-4ab0-be06-84812b85ff38': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='{"sync": "false", "sync_device_count": "2"}, "fcm_options": {"analytics_label": "wenote_analytics_label"}}}\''),
#   '680566d1-bd70-4abf-b9d9-921d2ce66c5e': Document(metadata={'source': 'data/qna.csv', 'row': 19}, page_content='</code></pre>'),
#   '92837ff1-5f8e-4ee1-b710-013791bea7ac': Document(metadata={'source': 'data/qna.csv', 'row': 20}, page_content='question_title: python get first x elements of a list and remove them\naccepted_answer_body: <p>Do it in two steps. Use a slice to get the first two elements, then remove that slice from the list.</p>\n<pre><code>first_list = lst[:2]\ndel lst[:2]\n</code></pre>'),
#   '06689088-1cf9-4ca3-8cbf-defc9a7881c4': Document(metadata={'source': 'data/qna.csv', 'row': 20}, page_content='<pre><code>first_list = lst[:2]\ndel lst[:2]\n</code></pre>\n<p>If you want a one-liner, you can wrap it in a function.</p>\n<pre><code>def splice(lst, start = 0, end = None):\n    if end is None:\n        end = len(lst)\n    partial = lst[start:end]\n    del lst[start:end]\n    return partial'),
#   'ca570ec8-f8e0-4cab-9d8c-171f59d8d437': Document(metadata={'source': 'data/qna.csv', 'row': 20}, page_content='first_list = splice(lst, end = 2)\n</code></pre>'),
#   '9e2f9706-c51e-4e7e-8277-1f1d90439212': Document(metadata={'source': 'data/qna.csv', 'row': 21}, page_content='question_title: NLTK download SSL: Certificate verify failed'),
#   '5d0b22d8-d916-42fa-ac98-4f949663efaa': Document(metadata={'source': 'data/qna.csv', 'row': 21}, page_content='accepted_answer_body: <p>The downloader script is broken. As a temporal workaround can manually download the punkt tokenizer from <a href="http://www.nltk.org/nltk_data/" rel="noreferrer">here</a> and then place the unzipped folder in the corresponding location. The default folders for each OS'),
#   '031a45ef-9a44-4b83-a206-b4c875bbb42b': Document(metadata={'source': 'data/qna.csv', 'row': 21}, page_content='unzipped folder in the corresponding location. The default folders for each OS are:</p>'),
#   '2f7396bd-b17c-484b-a614-238c0dea2d5f': Document(metadata={'source': 'data/qna.csv', 'row': 21}, page_content='<ul>\n<li>Windows: <code>C:\\nltk_data\\tokenizers</code></li>\n<li>OSX: <code>/usr/local/share/nltk_data/tokenizers</code></li>\n<li>Unix: <code>/usr/share/nltk_data/tokenizers</code></li>\n</ul>'),
#   '94f8f4ed-547d-42f7-a21f-70197b956787': Document(metadata={'source': 'data/qna.csv', 'row': 22}, page_content='question_title: pytest: how to use capsys to check stdout/stderr, and also have it print stdout/stderr if the test fails?'),
#   'd88a784d-c02b-442f-8cc9-6986d9dd9f49': Document(metadata={'source': 'data/qna.csv', 'row': 22}, page_content="accepted_answer_body: <p>You're seeing the correct behaviour.  When <code>capsys.readouterr()</code> is called, it consumes the captured output.  Hence, any output to stdout and stderr will no longer show up in the test report.  But any new output which you create after this and do not consume will"),
#   '4c5d02c7-dc5f-4065-bde4-ea5c38a3acd3': Document(metadata={'source': 'data/qna.csv', 'row': 22}, page_content='report.  But any new output which you create after this and do not consume will still be reported, so you can get the full output back in the report by simply writing it to the output streams once more:</p>'),
#   '92ec32a3-7a4b-4da2-a0b8-fbb4a8147346': Document(metadata={'source': 'data/qna.csv', 'row': 22}, page_content='<pre><code>def test_result_and_stdout(capsys):\n    result = method_under_test()\n    out, err = capsys.readouterr()\n    sys.stdout.write(out)\n    sys.stderr.write(err)\n    assert out.startswith(&quot;Hello&quot;)\n    assert result == 42\n</code></pre>'),
#   '33d1500f-5bc8-4a43-b6cf-47db1242a3b7': Document(metadata={'source': 'data/qna.csv', 'row': 23}, page_content='question_title: Cannot run visio macro using python'),
#   '92d21524-49b1-4d74-a4ac-3d495417671b': Document(metadata={'source': 'data/qna.csv', 'row': 23}, page_content='accepted_answer_body: <p>In Visio the Application object doesn\'t have a <code>Run</code> method, but there is an <a href="https://learn.microsoft.com/en-us/office/vba/api/visio.document.executeline" rel="nofollow noreferrer"><code>ExecuteLine</code></a> method on Document.</p>'),
#   '04de320f-e546-4a8c-a617-0226687abeb2': Document(metadata={'source': 'data/qna.csv', 'row': 23}, page_content='<p>So if your Visio document had a VBA procedure like this:</p>\n\n<pre class="lang-vb prettyprint-override"><code>    Public Sub SayHello(ByVal name As String)\n        MsgBox "Hello " &amp; name &amp; "!", vbOKOnly\n    End Sub\n</code></pre>\n\n<p>then the following Python would work:</p>'),
#   '650f0b08-ecfd-4179-8c55-b511930a774c': Document(metadata={'source': 'data/qna.csv', 'row': 23}, page_content='<p>then the following Python would work:</p>\n\n<pre class="lang-py prettyprint-override"><code>doc.ExecuteLine(\'ThisDocument.SayHello "Bob"\')\n</code></pre>'),
#   '0237493e-a00f-4c39-97da-45ea4f197bd7': Document(metadata={'source': 'data/qna.csv', 'row': 24}, page_content='question_title: Counting the Frequency of words in a pandas data frame\naccepted_answer_body: <p>IIUIC, use <code>value_counts()</code></p>'),
#   '9ac2f0f9-fadb-4cde-9dac-361b32be9229': Document(metadata={'source': 'data/qna.csv', 'row': 24}, page_content="<pre><code>In [3361]: df.Firm_Name.str.split(expand=True).stack().value_counts()\nOut[3361]:\nSociety       3\nLtd           2\nJames's       1\nR.X.          1\nYah           1\nAssociates    1\nSt            1\nKensington    1\nMMV           1\nBig           1\n&amp;             1\nThe           1"),
#   '5e6fe3da-955b-40c4-9bd5-01bc93a1eb63': Document(metadata={'source': 'data/qna.csv', 'row': 24}, page_content='MMV           1\nBig           1\n&amp;             1\nThe           1\nCo            1\nOil           1\nBuilding      1\ndtype: int64\n</code></pre>'),
# ...
#   '9db8010d-5274-494e-aa11-7f216bdb7942': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='&quot;req&quot;: {\n    &quot;url&quot;: &quot;/&quot;,\n    &quot;headers&quot;: {\n      &quot;host&quot;: &quot;localhost:8000&quot;,\n      &quot;user-agent&quot;: &quot;Mozilla...&quot;,\n      &quot;accept&quot;: &quot;text/html,application/xhtml+xml,...&quot;\n    },'),
#   '823789c6-4104-4c85-876d-a72790035a5b': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='},\n    &quot;method&quot;: &quot;GET&quot;,\n    &quot;http_version&quot;: &quot;1.1&quot;,\n    &quot;original_url&quot;: &quot;/&quot;,\n    &quot;query&quot;: {}\n  },\n  &quot;res&quot;: {\n    &quot;status_code&quot;: 200,\n    &quot;status&quot;: &quot;OK&quot;\n  }\n}\n</code></pre>'),
#   'd560e414-84f6-4d77-ab0e-746a1c1b25a0': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='&quot;status&quot;: &quot;OK&quot;\n  }\n}\n</code></pre>\n<h2>Using a custom Python logger separate from <code>uvicorn</code> loggers</h2>'),
#   'ef9650d6-3532-4583-a531-8834f4605f45': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='<p>In case one wished having a separate custom Python logger instead of customising the existing <code>uvicorn</code> loggers, as demonstrated earlier, they would need to add a <code>StreamHandler</code> and/or <code>FileHandler</code> and set the desired level, i.e., <code>DEBUG</code>,'),
#   '6ce8c1c8-b98b-4d3c-8544-875d46a0394b': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='<code>FileHandler</code> and set the desired level, i.e., <code>DEBUG</code>, <code>INFO</code>, <code>WARNING</code>, etc.—the lowest level offered by Python\'s <code>logging</code> module is <code>DEBUG</code>, with the <a href="https://docs.python.org/3/howto/logging.html#when-to-use-logging"'),
#   'cd0931b1-cdfe-4b6f-8ba0-42989bd71a17': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='the <a href="https://docs.python.org/3/howto/logging.html#when-to-use-logging" rel="nofollow noreferrer">default level being <code>WARNING</code></a> (if one is interested in adding a custom log level, see <a href="https://stackoverflow.com/q/2183233">this post</a>).</p>'),
#   '5080067c-20b5-42ab-b0eb-1c9d7ff1b0e9': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='<p>You could either do that using a <code>dictConfig()</code>, as shown earlier, or directly using the <code>logging</code>\'s module functions and classes. The following example is based on <a href="https://stackoverflow.com/a/70899261/17865804">this answer</a>, which demonstrates <strong>how to'),
#   'dbc3827f-ef2d-4d91-af1d-821f898ca041': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='answer</a>, which demonstrates <strong>how to customise the format of the logging messages in JSON</strong> (hence, see that answer, if you are looking for a similar format presented in the previous section), as well as <a href="https://stackoverflow.com/a/73464007/17865804">this answer</a> that'),
#   'fa179c9c-9b3b-4175-b9af-cf89c37cd626': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='as <a href="https://stackoverflow.com/a/73464007/17865804">this answer</a> that shows <strong>how to log both the request and response bodies</strong> in the background.</p>'),
#   'a46598e2-df7b-40dc-9be6-5d1d3cf151ef': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='<p>More details and examples can also be found in Python\'s official documentation page <a href="https://docs.python.org/3/howto/logging.html" rel="nofollow noreferrer">here</a>. You may also want to have a look at all the available <a'),
#   '728962b4-eda6-428c-a0e8-82fd3d6e079b': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='noreferrer">here</a>. You may also want to have a look at all the available <a href="https://docs.python.org/3/library/logging.html#logrecord-attributes" rel="nofollow noreferrer"><code>LogRecord</code> attributes</a> that can be used to format the logging records.</p>'),
#   '0ffd4e9f-4954-4f4a-a08f-3e314b082015': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='<p>Setting <code>log_level=&quot;trace&quot;</code> in <code>uvicorn.run()</code> would set the level of the <code>uvicorn</code> logger to <code>TRACE</code>, as described earlier—in case one needed that as well. Also, one could still customise the <code>uvicorn</code> loggers, if they wish, using'),
#   '6429ec82-34e0-4a73-a5fb-86729e3eba85': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='one could still customise the <code>uvicorn</code> loggers, if they wish, using the <code>LOGGING_CONFIG</code> dictionary provided in the previous section and passing it to the settings, i.e., <code>uvicorn.run(..., log_config=settings.LOGGING_CONFIG)</code>. In that way, one could get the'),
#   'e5045f59-5f7d-4def-9cb0-017d69772ac9': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='log_config=settings.LOGGING_CONFIG)</code>. In that way, one could get the <code>uvicorn</code> logs in an elegant format and have them saved to a file on disk as well.</p>'),
#   'cf4df1b0-2bd0-41ed-8b95-6b466f8fbf6e': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='<h2>Working Example</h2>\n<pre class="lang-py prettyprint-override"><code>from fastapi import FastAPI\nimport logging\nimport uvicorn\nimport sys'),
#   'f4667d08-9292-4fcc-83c7-cbc55dc09584': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='app = FastAPI()\n\nlogger = logging.getLogger(__name__)\nlogger.setLevel(logging.DEBUG)\nformatter = logging.Formatter(&quot;%(asctime)s [%(processName)s: %(process)d] [%(threadName)s: %(thread)d] [%(levelname)s] %(name)s: %(message)s&quot;)'),
#   '5339c232-929a-410b-861e-26b0012f2ae3': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content="stream_handler = logging.StreamHandler(sys.stdout)\nstream_handler.setFormatter(formatter)\nfile_handler = logging.FileHandler(&quot;info.log&quot;)\nfile_handler.setFormatter(formatter)\n\nlogger.addHandler(stream_handler)\nlogger.addHandler(file_handler)\n\nlogger.info('API is starting up')"),
#   '460012b4-ed7c-4e01-887c-c65d4544706d': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content="logger.info('API is starting up')\n\n\n@app.get('/')\nasync def main():\n    logger.info('GET /')\n    return 'ok'"),
#   '398d8226-376b-46a8-9c0c-fcd95cbc7d21': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content="if __name__ == '__main__':\n    uvicorn.run(app, log_level=&quot;trace&quot;)  # or `log_config=settings.LOGGING_CONFIG`\n</code></pre>\n<h2>Final Note</h2>"),
#   '3e577468-4e44-45ba-87cb-bafe64482856': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='<p>In each of the above cases, one may wish to initialise the <code>logger</code> at startup inside a <code>lifespan</code> handler, and then add it to <code>request.state</code>, so that it can be accessed outside the main file of the application as well; for instance, from a submodule that uses'),
#   '9c978798-bd25-461e-8ce4-f125e46e8131': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='main file of the application as well; for instance, from a submodule that uses <code>APIRouter</code> to create <em>endpoints</em>, lying inside a <code>routers</code> package, which is normally the case when building <a href="https://fastapi.tiangolo.com/tutorial/bigger-applications/"'),
#   '4e836839-4367-4134-b69c-0cd19d37ad62': Document(metadata={'source': 'data/qna.csv', 'row': 100}, page_content='building <a href="https://fastapi.tiangolo.com/tutorial/bigger-applications/" rel="nofollow noreferrer">Bigger Applications</a>. To do that, please have a look at <a href="https://stackoverflow.com/a/76322910/17865804">this answer</a>.</p>'),
#   '4dbf44a2-fcd9-488c-be16-0e92a0d6f881': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='question_title: SQLite 3: Sum a column and also show last value\naccepted_answer_body: <p>Here are two options in the same sql:</p>\n<pre class="lang-sql prettyprint-override"><code>--      S a m p l e    D a t a :  \nCreate Table tbl AS\nSelect \'John\' as a_name,  5 as a_value,  2021 as a_year Union All'),
#   '3afb39e7-4fea-44fd-94da-4d7618882110': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content="Select 'John' as a_name,  5 as a_value,  2021 as a_year Union All\nSelect 'John',      10,        2022  Union All\nSelect 'John',      6,         2023  Union All\nSelect 'Kat',       20,        2021  Union All\nSelect 'Kat',       10,        2022  Union All\nSelect 'Kat',       12,        2023;"),
#   '2f247fc3-6a30-49a8-aeb2-76b659fe4f31': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='Select \'Kat\',       12,        2023;\n</code></pre>\n<pre class="lang-sql prettyprint-override"><code>--      S Q L : \nSelect   t.a_name, Sum(t.a_value) as Total,\n         LAST_VALUE(t.a_value) Over(Partition By t.a_name Order By t.a_year) as last_year_1,'),
#   '3797ed10-eaf2-4d0a-ba7f-be6ca4c47234': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='Max(Case When a_year = Cast(StrFTime(\'%Y\', Date(\'now\')) as Int) - 1  Then a_value End) as last_year_2\nFrom     tbl t\nGroup By a_name\nOrder By a_name;\n</code></pre>\n<p>R e s u l t :</p>\n<div class="s-table-container"><table class="s-table">\n<thead>\n<tr>'),
#   '9d2bcbb1-a29f-44af-8def-5bf7bcd10f33': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='<div class="s-table-container"><table class="s-table">\n<thead>\n<tr>\n<th style="text-align: left;">a_name</th>\n<th style="text-align: left;">Total</th>\n<th style="text-align: left;">last_year_1</th>\n<th style="text-align: left;">last_year_2</th>\n</tr>\n</thead>\n<tbody>\n<tr>'),
#   '9f2d8466-82f3-4d06-bedf-52c72f95c4ae': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='<th style="text-align: left;">last_year_2</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td style="text-align: left;">John</td>\n<td style="text-align: left;">21</td>\n<td style="text-align: left;">6</td>\n<td style="text-align: left;">6</td>\n</tr>\n<tr>\n<td style="text-align: left;">Kat</td>'),
#   'a0d9a208-e569-4f21-92a7-1b558ffc0549': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='</tr>\n<tr>\n<td style="text-align: left;">Kat</td>\n<td style="text-align: left;">42</td>\n<td style="text-align: left;">12</td>\n<td style="text-align: left;">12</td>\n</tr>\n</tbody>\n</table></div>\n<p><a href="https://dbfiddle.uk/Z7AsjQFI" rel="nofollow noreferrer">fiddle</a></p>'),
#   '4a8a966a-6b48-4a6d-88a4-51941b212dbd': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='<p>For some unknown reason the above code works as is - but the LAST_VALUE() without following Max() column gives faulty result. <strong>Thanks choroba</strong> for noticing and commenting...</p>\n<p>So here are both codes separately that works ok ...\n... with just normal aggregation</p>'),
#   '97aa1e4e-487b-4fef-9307-7c6373ee56db': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='... with just normal aggregation</p>\n<pre class="lang-sql prettyprint-override"><code>Select   t.a_name, Sum(t.a_value) as Total, \n         Max(Case When a_year = Cast(StrFTime(\'%Y\', Date(\'now\')) as Int) - 1  Then a_value End) as last_year_1\nFrom     tbl t\nGroup By a_name\nOrder By a_name;'),
#   'a435035e-bb43-4cc7-99ba-f4322a6d5d0b': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='From     tbl t\nGroup By a_name\nOrder By a_name;\n</code></pre>\n<p>... OR with just analytic functions (but with Distinct keyword) ...</p>\n<pre class="lang-sql prettyprint-override"><code>Select   Distinct  \n         t.a_name, Sum(t.a_value) Over(Partition By t.a_name) as Total,'),
#   'c0dda829-e1b4-4541-bf8a-aaf15f2fb287': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='t.a_name, Sum(t.a_value) Over(Partition By t.a_name) as Total,\n         LAST_VALUE(t.a_value) Over(Partition By t.a_name Order By t.a_year\n                                    Rows Between Unbounded Preceding And Unbounded Following) as last_year_1\nFrom     tbl t;\n</code></pre>'),
#   '85ca37be-5530-480c-b67d-7ae6383b15fc': Document(metadata={'source': 'data/qna.csv', 'row': 101}, page_content='From     tbl t;\n</code></pre>\n<p><a href="https://dbfiddle.uk/OL3I0741" rel="nofollow noreferrer">fiddle</a></p>'),
#   '32b6d1e7-7720-44cd-943a-24bac66d60bd': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content='question_title: How can I make a button inside of a frame affect something outside its own frame with Custom TKinter?\naccepted_answer_body: <p>I assume you want to reuse the <code>switch_frame</code> function in the <code>viewGames</code> function.'),
#   '5535e589-1c53-41db-aa43-2f8ecde6892b': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content='For this to work, you need to use an instance of your App class (app in lowercase).\nThen clicking the &quot;View Game List&quot; button will do the same thing as clicking the &quot;Switch to Scroll Frame&quot; button.'),
#   '936e76b5-510b-442d-9ef0-e30edf0c36a3': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content='The <code>app</code> and <code>ScrollFrame</code> names are defined in the same space as the <code>FunctionsSidebarFrame</code> class.</p>\n<pre><code>def viewGames(self):\n    print(&quot;View Games&quot;)\n    app.switch_frame(ScrollFrame)\n    # or\n    # self.master.master.switch_frame(ScrollFrame)'),
#   '485d02a3-9c1f-4114-912e-e61e867e3877': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content='# or\n    # self.master.master.switch_frame(ScrollFrame)\n</code></pre>\n<p>However, the way you switch frames in the <code>switch_frame</code> function creates new objects every time the function is called.</p>\n<pre><code>new_frame = frame_class(self) # new object'),
#   '394c9d13-dbf1-4ef2-8c92-69ca9f360734': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content='<pre><code>new_frame = frame_class(self) # new object\nif self.current_frame is not None:\n    self.current_frame.grid_remove() # hide the previous frame, but it still exists\nself.current_frame = new_frame\nself.current_frame.grid(row=0, column=1)\n</code></pre>'),
#   '070cb6b8-7047-48ef-856b-33817c3216db': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content="self.current_frame.grid(row=0, column=1)\n</code></pre>\n<p>If you add <code>print(self.winfo_children())</code> to the <code>remove_frame</code> function, you'll see a group of frame objects at the end of the list (after &quot;.!ctkbutton6&quot;)."),
#   '3581595b-a5ea-4bc3-80cf-03346e7ad75a': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content='The number of objects depends on how many times the user clicks the buttons that call the <code>switch_frame</code> function.</p>\n<p>To make the buttons switch frames instead of creating new ones, you need to change the <code>switch_frame</code> function.</p>\n<p>Changes:</p>\n<ul>'),
#   '8bd53404-0f7d-4a36-afa0-c730a25a070b': Document(metadata={'source': 'data/qna.csv', 'row': 102}, page_content='<p>Changes:</p>\n<ul>\n<li>Create one instance of <code>GeneralFrame</code> and one instance of <code>ScrollFrame</code> in <code>__init__</code> (class App).</li>\n<li>Use <code>grid_remove</code> to hide frames.</li>\n<li>Pass frames (not classes) as arguments to commands.</li>'),
#   ...}}

# %%
vector_store.similarity_search("error when importing langchain.text_splitter Python", k = 2)
# Out:
# [Document(metadata={'source': 'data/qna.csv', 'row': 1}, page_content='question_title: @roo_validator error when importing langchain.text_splitter Python\naccepted_answer_body: <p>I was using LangChain 0.0.20 and I got the same issue. Upgrading to Python 3.9 and LangChain 0.0.224 fixed this issue for me.</p>'),
#  Document(metadata={'source': 'data/qna.csv', 'row': 913}, page_content='<pre><code>from langchain.llms.openai import OpenAI\n</code></pre>\n<p>Maybe your python version installed an early verison of langchain due to dependency requirements</p>')]

# %%
vector_store.save_local(folder_path="data", index_name="faiss_index")

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '36a71fcd-c1db-4b4a-89cf-f7dbbe2329df',
#  1: '33db2ce7-ca36-4327-af2c-a270a996c601',
#  2: '62c8cbcb-cd83-4a4f-a5db-7e6805cc7069',
#  3: '11554a89-53d4-41fd-a500-4ab251a384fd',
#  4: '4a88a6d8-fe65-40b7-a38d-31ce63c63b9e',
#  5: '0b154506-6614-49ba-a92a-4227c57ca9be',
#  6: 'fc8df0ae-b616-451d-a816-0c2d3a53e47d',
#  7: 'fd08ee6e-5fbd-4fcb-8bbb-ba34d2f3c729',
#  8: '4c5906f0-c7fa-4222-a704-788a3ad7822b',
#  9: 'eea4fd52-61ad-42ea-ba9c-319f9cfd2a4f',
#  10: '0c6fbcb5-176a-4f06-bd69-f15e0cd81878',
#  11: '4f9c827c-2dc5-4bb8-9306-f32d80d2b037',
#  12: 'b41a94cd-23f3-49f6-befc-4bd5c119f826',
#  13: '51372f72-0681-426c-91ea-38a2ffe613ef',
#  14: 'a0a55c59-2f09-4c6a-ae0b-b4e9acfe9a8e',
#  15: 'c9bdf2e7-5744-48ce-9492-03b37e62bcce',
#  16: '85d1158d-a67b-4333-9b2b-6735a2cc424e',
#  17: '30932a60-7958-489a-af02-0bac8e566d40',
#  18: 'f63fe398-dd4d-4a2f-8168-1577216fc0a9',
#  19: 'bb35783c-6560-47d0-b13a-51818b492135',
#  20: 'e6282f1a-efc4-49b8-980c-e2d95b7940c2',
#  21: '291d4e6f-5654-4ab9-89f2-c9596fa23b1e',
#  22: '8ce0fbde-888d-491b-9c58-1082af5eb994',
#  23: '0101a9bc-8068-4cb0-b51d-4e3d1478ab02',
#  24: '986db389-3829-405d-9d7f-4e6ddc580211',
#  25: '80a9d4a3-1514-4f48-86a6-75d78165bd15',
#  26: 'ee19d2aa-3a44-4aa5-87ea-d64c0cc82ea2',
#  27: 'b50143b8-e259-4178-b385-8da8706a5efa',
#  28: '570c18bd-8047-4b11-8c41-743b433f3362',
#  29: '0af56541-28ed-4d5d-a8db-f07af41ef0f9',
#  30: 'a5dcb2d6-8f48-4303-9a56-c2ad0b3f9522',
#  31: '9f3b423e-f6e8-4039-963d-3d419f4c83fa',
#  32: '7ba31c7d-5225-4a2a-afaa-9d45fa24cabd',
#  33: '3fc00240-c100-4561-9c5f-68e00f9317c3',
#  34: '01ce7569-1811-41d9-90f7-5866b6dd0ee2',
#  35: '274ba112-8ec3-49a8-88dd-f2a3ceee7971',
#  36: '830d3c5b-b772-4cf0-b68e-b05813ea5a7c',
#  37: 'f7be6d67-db03-4c3a-81f3-0790e3098055',
#  38: 'a1532f73-1913-4f8e-a234-15edcf90f6ca',
#  39: 'f346a73c-0dfd-4868-a9d1-cc8f9b5009e9',
#  40: '22b554d2-05a7-4852-a11b-1c7f914fd445',
#  41: '257c87c0-3352-48d8-ab89-69f2173085aa',
#  42: '5d03f11b-b66b-4e7b-8f30-74fcae1ff501',
#  43: 'd3fed37f-1016-4d15-aa84-c586b5284de2',
#  44: '806839ea-1ba9-4be8-8849-9db6bcb78f1c',
#  45: 'e293cb58-3768-456e-88dc-65cb24ffd784',
#  46: 'a49169d6-2522-42d1-8ff5-8d8ee9fb1fe1',
#  47: 'c08db85d-15a5-4a7d-aae5-a2d54e25aca8',
#  48: '27bcd29e-68f8-405b-8edf-377f3e7daa3e',
#  49: '24d95805-3c6b-454d-90b0-9b775eae2731',
#  50: '1985464e-399d-4bf4-b167-fdfe066f5a7f',
#  51: '26e5b173-c180-49ab-afb3-b93bcd9ae218',
#  52: '9f3f1f22-350e-4471-b138-9da7f1f5a686',
#  53: 'ec433722-6204-4ac7-a7ed-4a08af0f384c',
#  54: 'e9db96cb-0718-4592-ab9b-fcf3a6df132b',
#  55: '327e0eef-d275-4e15-8144-74f12547839e',
#  56: 'e47dac4d-f6a3-45fa-84e6-934703bce63a',
#  57: '77f76100-4d93-4cb4-8aa4-e7d0df690ed1',
#  58: '28010317-cee1-4b12-b5c9-4cc21035c47e',
#  59: 'e2515e84-d9eb-4cca-9611-99de37b41dc2',
#  60: '4467c99c-ff1a-45fa-ae45-000986234a87',
#  61: '7d4149fd-713e-41a7-ba48-3efc8ab18f86',
#  62: 'b525274d-065b-4d19-b01b-c0fac743400a',
#  63: 'e67981ab-8894-45af-b384-10693ff21120',
#  64: 'f84aa4d3-2876-45c8-8bba-4d73fa60c28e',
#  65: '8df72242-9e5a-4a7c-b8eb-442028e35d76',
#  66: '05abdd16-856e-4ed4-ad8b-896759521f42',
#  67: 'f4f10bf2-d89e-4a35-a2f1-0161c8fa9dcd',
#  68: '636bf0b7-59b4-47fe-9d0e-62debc369587',
#  69: '2c33ab4a-dab9-43c0-b4bd-ac311cfb7440',
#  70: '47380716-71dc-4c0b-a98e-2c991238ee62',
#  71: '939ca1df-762c-435b-9cf4-69166790e392',
#  72: '42e0a3e6-c536-440e-87a7-e11f2b86a0ec',
#  73: '12fa9e70-39b9-431c-bac8-e12648c5537d',
#  74: '17470fd7-3d06-475a-84d7-0c2d5b105495',
#  75: '7cbc051a-eed1-4548-80bf-02810638a689',
#  76: '1ca0d9a1-7677-4b19-a9a4-b0b3e50dfaac',
#  77: '1c27eecf-39d6-410e-82ba-7675aaf314df',
#  78: 'ea590fe3-f247-48f1-ba31-14440b4f7230',
#  79: '6236b7ea-cbf0-4c9e-9d93-9e20a3db1e10',
#  80: 'f4790592-28cd-4dc6-a259-3e1c1f86b377',
#  81: 'd5849481-b305-49c2-a846-34ae5a526c88',
#  82: '3a779c42-aa5e-4ac3-a851-099ec03aabf8',
#  83: 'ed946dd3-1152-48ec-a130-db4befbb99e9',
#  84: '9a3080f6-7807-4256-95cd-7980c0ed6c41',
#  85: '67ab9741-095b-45d0-b34b-25cd19ae9e33',
#  86: 'b51eada2-1905-413c-baa5-47b5183a6173',
#  87: '25e516e9-d0fe-4aa6-9e74-527fd92d2c7d',
#  88: '370967c3-2830-470a-8ad4-87831ee669e4',
#  89: 'b8280f53-64c4-4774-b0cd-ecafe50a1990',
#  90: '4e7c825f-b54f-48de-8c34-526316378038',
#  91: '8741f72d-391b-44ea-84d8-0ca32be9bbcd',
#  92: 'b23516cd-05a8-40a7-8b33-617b50f34bcd',
#  93: '4fc91c62-aedc-4c65-bfab-5d79af9b9563',
#  94: '460be370-3e99-4071-8248-a4f141a1cfe0',
#  95: '798f8dff-54f8-42c7-9a98-6fc564f673bb',
#  96: 'dfe505fe-7af5-49de-b3ad-a4bd6108b2b1',
#  97: 'c55ab9df-a963-4cd1-9141-622e06467dfb',
#  98: '8e976773-34c1-4871-b432-c2256a2f5974',
#  99: '1b432a8f-a913-4352-84c6-fd171df70afa',
#  100: 'c66b2b20-cb86-495c-8490-e421afb321fc',
#  101: 'b2b869c3-30c2-4bca-b6ff-3a6ee43ce3d0',
#  102: 'a66ed8cc-0ac6-496a-a15b-9665d01e614c',
#  103: '585f01c2-f89f-4a0d-a6c4-2cf18ec4d28b',
#  104: 'f3e69b48-0fb1-4f85-935e-59829a961e7a',
#  105: 'a1f81029-2d22-4bd8-9818-43e4a748634e',
#  106: '24db81ce-5037-4212-9e40-b02121a22f1b',
#  107: '6c619291-66e7-4fd1-bdd4-ac5aa28bc600',
#  108: '31254c5a-b17e-447b-ac7f-52ca5ceae134',
#  109: '55c016f9-c703-4c34-85a9-b300c6a05ae9',
#  110: '89f4edc9-5afa-413c-9f72-86d8e2f0800a',
#  111: 'b5209749-751c-43e8-a9a6-0581299482fa',
#  112: 'f4b23a28-edef-4db6-bf4b-5099affc1553',
#  113: 'fb024357-583a-4218-823e-5a5b5a8c8be8',
#  114: 'dbb0e48f-7956-420e-82b8-da421588240d',
#  115: '19611081-1105-408b-b5c5-c6d429c516e8',
#  116: '084eb25c-9106-4a04-8060-35e711c92f9d',
#  117: '30d097bb-f0ab-4325-97c2-b44887fae2cd',
#  118: '89b40944-0adc-48d0-b689-f96aafb3e470',
#  119: '3bbef237-1ffb-49f0-a306-4dba6114d24b',
#  120: 'b43468bd-50a8-4d3e-ba1d-1c3a1cd020f6',
#  121: '252526aa-1cf9-45cd-badc-268560611e5f',
#  122: 'b9d7090b-0349-45c2-8b0d-7836a38d84c4',
#  123: '37e93dc9-ceba-445e-8711-46575095c63d',
#  124: '97123fd6-9865-47f3-923f-f5f4c008ac9f',
#  125: '91fe0432-63f5-47d7-8a3b-493633fd5e15',
#  126: 'f08bb506-1d57-47b1-8312-c55ceef3bebd',
#  127: '8d105ab7-4278-4328-8b5c-b0db551f83bd',
#  128: 'fc093bd1-3dae-4ab0-be06-84812b85ff38',
#  129: '680566d1-bd70-4abf-b9d9-921d2ce66c5e',
#  130: '92837ff1-5f8e-4ee1-b710-013791bea7ac',
#  131: '06689088-1cf9-4ca3-8cbf-defc9a7881c4',
#  132: 'ca570ec8-f8e0-4cab-9d8c-171f59d8d437',
#  133: '9e2f9706-c51e-4e7e-8277-1f1d90439212',
#  134: '5d0b22d8-d916-42fa-ac98-4f949663efaa',
#  135: '031a45ef-9a44-4b83-a206-b4c875bbb42b',
#  136: '2f7396bd-b17c-484b-a614-238c0dea2d5f',
#  137: '94f8f4ed-547d-42f7-a21f-70197b956787',
#  138: 'd88a784d-c02b-442f-8cc9-6986d9dd9f49',
#  139: '4c5d02c7-dc5f-4065-bde4-ea5c38a3acd3',
#  140: '92ec32a3-7a4b-4da2-a0b8-fbb4a8147346',
#  141: '33d1500f-5bc8-4a43-b6cf-47db1242a3b7',
#  142: '92d21524-49b1-4d74-a4ac-3d495417671b',
#  143: '04de320f-e546-4a8c-a617-0226687abeb2',
#  144: '650f0b08-ecfd-4179-8c55-b511930a774c',
#  145: '0237493e-a00f-4c39-97da-45ea4f197bd7',
#  146: '9ac2f0f9-fadb-4cde-9dac-361b32be9229',
#  147: '5e6fe3da-955b-40c4-9bd5-01bc93a1eb63',
#  148: 'e386a2c3-6cd3-4839-8dc7-2ab185305b0d',
#  149: '8e496824-2531-49dd-9554-aaeee6090338',
#  150: '7af6c101-ec70-4bdd-95c7-3a0b545ff7db',
#  151: '65acc220-a541-4b0c-a0fa-31cb24ea9981',
#  152: 'b7e7ae6f-b06a-46e0-bdc1-f926f5155f15',
#  153: 'ae775d88-480e-430a-8f0e-89fccd686ea0',
#  154: 'ca64cddb-72cb-4039-acfa-66100ea4eddb',
#  155: '10bab603-2e09-4668-8ffd-246b5ec46e99',
#  156: 'a2fdb9cb-b124-4c10-ad67-bd6dafc57e56',
#  157: '79b8dbc9-6971-4452-a4ae-31184841314b',
#  158: '6d9b0dd2-02d1-42a6-a706-ed2a26235730',
#  159: 'e8d7eca6-cf3c-48b7-a340-1504f35edc2e',
#  160: '4c0ebe15-166f-4c98-ac88-5889fbfdda27',
#  161: '1b86af3f-ca49-4109-beac-f77dff861a6b',
#  162: '4d5c2491-4f16-4b67-9095-528656ad5a52',
#  163: 'ab4b7846-b7e8-4f7a-9fcc-d43b5071495f',
#  164: '66aff8c8-1efc-49fe-87b5-1e482d4edd18',
#  165: 'df3ad3b2-c3ae-44ff-862a-571adab6478d',
#  166: '870b32f4-e7c8-4e66-af85-e8854d45922d',
#  167: 'a5520f0b-f169-4fca-8929-b48472df23ee',
#  168: 'f68bdff9-b39b-44cb-9d65-17f940a8c13d',
#  169: 'c08e615e-ad55-4fd5-b9bd-85db7b9a2f80',
#  170: '7d724a14-1fea-427b-bdc3-3191d83e8f4b',
#  171: 'a3b758c5-c91c-46f9-abe3-6368748ef820',
#  172: '288543f1-1407-4b38-92e7-03b187c06b38',
#  173: 'd2223bce-6447-4422-9dc1-8ad2b45ce9b0',
#  174: '290e1799-cf28-406b-9eeb-b097c1c4abd4',
#  175: '302b7c27-e756-4028-ade7-7f2cc5cf07f3',
#  176: '33069add-a98b-44e6-8800-77dcb47dd934',
#  177: '6ea723df-3a88-493d-8be7-b30acce35cc0',
#  178: 'be2e85f2-2c95-4d27-996f-40cf20b9d977',
#  179: 'c65266cd-fa0e-434e-93c3-630a13a37376',
#  180: '03de1a8a-7eda-4bc5-a231-80b4ed62f565',
#  181: '359162d9-27ad-41f1-92bd-7d284bdddd9a',
#  182: 'a3eb851e-e383-4f9a-ab66-8ebed6aefe2d',
#  183: '182b0129-a60f-4acb-a419-bd1e7661f1a4',
#  184: '97f75a56-8bd2-4a49-b78d-08cb7e01fbce',
#  185: 'f431220b-a48f-4dc3-a236-5965c9da7f1f',
#  186: 'd88fa9ed-4af3-41f1-b051-a3a50e373d74',
#  187: '6864784c-9560-4ff4-8991-18b5138e3eb8',
#  188: 'cf737146-7fa6-404a-8445-35824f9eea70',
#  189: '625d08de-9065-4a72-9ade-6a49b0f61c14',
#  190: 'ec5ecc84-8e28-4a91-9ac4-c720ab2cda80',
#  191: '4d50b462-820d-42b4-a009-911bcb114b92',
#  192: '2945b643-06fa-4e46-8a70-f99adbd292ea',
#  193: '85def336-5eb8-45aa-9f08-8f175004824c',
#  194: 'f54ef64d-c355-49db-8066-a54fe47d9626',
#  195: '0e29ae27-9f74-447d-a06f-e65a38c8368b',
#  196: 'e0775c36-dfad-4aa2-a72b-9ba887d1f367',
#  197: 'b687721e-f749-4e12-8226-eb2b37314cdd',
#  198: '8636daa6-ad43-4b8c-99ef-f574c03de83a',
#  199: '7deee9bd-9a95-4718-af81-0de9b427aa11',
#  200: 'c88e4abb-1a90-4f28-9edb-cce09e09fbcc',
#  201: '2ed10c5f-7d0d-402e-85d5-17a4e271351c',
#  202: '139f20c5-417b-49bc-a07e-aaf8b469855b',
#  203: '893ac3c4-abc8-4ec5-892f-7dd2b1c2a420',
#  204: '40f3a97e-1985-4899-a56b-c293a4135303',
#  205: '96faf6c9-582d-4bc7-b0d9-1f324767ba39',
#  206: '8441057d-14a4-4d2a-aa8d-e320c25fdb92',
#  207: '840504c1-baa5-408a-ba1c-118660ebfb61',
#  208: 'f4d2f930-a0b6-4510-ac05-2c1a07cd20cb',
#  209: '397d8f98-87f7-4717-a4e0-1782dba7d3d5',
#  210: '2ff23315-1dd9-4981-8b6c-d51fd2d3868f',
#  211: '115e91f1-e26c-4147-9192-b8e0a178b972',
#  212: '48442c79-8e35-4aef-9cd1-e3a585070654',
#  213: 'cdf5a47b-dcbc-42e4-beab-2e8e651bf061',
#  214: '0092f6f6-cd71-43af-8a97-4bb1972e479b',
#  215: 'ddfdd31c-1cf3-4ea8-a985-361ba0f3617c',
#  216: 'd924938f-bb87-483d-94c9-64af2e7e5d30',
#  217: 'a8ed4e90-79a1-408c-9179-b7b3c4a38107',
#  218: '6ea4472e-a717-4408-a8d4-570182c05dde',
#  219: 'cb9e97b3-f15f-4156-9823-d91569209240',
#  220: '38308ff9-90b6-4aad-9148-b93dfbb14a34',
#  221: '68bffaa4-93ec-4c5b-bb85-fa4306951662',
#  222: '316e3452-4e53-493e-9d2d-3afc76f7195b',
#  223: 'eca1d772-2f51-4393-88ae-f3a18e549328',
#  224: 'c257a73b-e951-43e9-8608-f3de8019e894',
#  225: '95f6fe72-c832-44a5-bdb9-da55a1012cda',
#  226: 'e7000e8b-e133-4f2d-b5ed-e6f7b2cbc5c0',
#  227: 'b45b0832-4791-48e6-bc08-06e7b25c953e',
#  228: 'fc8193ac-55ef-493e-b653-caabb5e37a79',
#  229: '4422d52a-a812-4e9a-9463-e29b42c9649b',
#  230: 'e08500f3-eeb1-4e1f-b86f-3a6721219094',
#  231: '6895fc0e-ebfa-4789-9c1e-4e76e32c91e1',
#  232: 'be012c5a-f2f9-41ca-9ea7-44def0affcbd',
#  233: '3482d4b1-8cf3-4d1f-b085-ee9c4067a015',
#  234: '4b4b1c4a-3e8c-4445-b26c-a7d7ba523aab',
#  235: 'fcaae13c-bfd1-4767-86a8-ca764e32e851',
#  236: '4df9999e-3163-49cb-84fd-b72481bde3d6',
#  237: '4ea437eb-a8c1-40e7-a97f-8a015ea21be9',
#  238: 'c40c6a8b-1a7b-439e-b903-65f24afc20b9',
#  239: 'e7593d18-c3ee-4a91-b1c2-54a3e57e2520',
#  240: '1d8c8093-170f-4ac0-9c26-d2e0fcc9fe29',
#  241: 'f4b33e67-559e-469d-8d38-43f2d47b4757',
#  242: '9a9c65d3-afa7-41fd-825f-63bb6fa27829',
#  243: '8c326ae5-a791-41d7-a4f9-b613ccdc5b8e',
#  244: 'ddadf9b3-9b28-48e1-9c80-23bb1495e8a4',
#  245: '4352f3ff-0a3d-41bf-b998-521d6730adc0',
#  246: '242e0b6d-6a05-4dde-90ba-bfe9bd4f39d8',
#  247: '0b0d6a9a-24f2-4872-a619-12863232c788',
#  248: '6f887f76-e5d7-45eb-bb26-022106abafb6',
#  249: 'c03a0a68-a970-472e-b405-48da1e5d94cf',
#  250: 'f1c65500-e1c7-4fe8-8d78-78e56800d4cb',
#  251: '78fc5c6e-1a3b-49b7-9b0e-a8b15eefd6ef',
#  252: '6f16e421-f614-4d58-9450-041d9c7a3786',
#  253: '558477bd-ca74-4918-aa16-7598319f274e',
#  254: '4a2d2d3a-969a-4acc-9e0b-d1bef389d2d8',
#  255: 'a090e9aa-4d58-4581-a814-5348c08dbbbc',
#  256: '9b9d8463-1d2d-42fd-987b-3c05aa6d3bed',
#  257: '8695ba22-7246-4443-92a2-34db8fe03c79',
#  258: '4465abfe-f760-45ad-82e0-b1cc4d9a7169',
#  259: '6406fd92-1059-4f54-b36d-4b6c10bb1faa',
#  260: 'c1ccb642-adb2-452e-b12c-a8d9569dd95b',
#  261: '3ba12d5b-5140-4542-b985-4b9e91dc032b',
#  262: '6a5a6216-553b-4bb3-89e9-ba5b59875c7f',
#  263: 'd642babc-756e-4ba7-89c2-eeab2895eef7',
#  264: 'eb4d997a-0bbf-412d-a38b-fe30039cdb07',
#  265: 'e2581f1b-6034-424f-970c-f8992cbd92f8',
#  266: '199ed941-0380-4e86-89d2-5eae9f954b90',
#  267: 'fb5dd6f8-e7ed-4ee3-8840-5e5c2b1c5853',
#  268: 'afd7628f-0d0f-441c-b5bd-61480c51f485',
#  269: '65abbefa-735d-4fa9-aea9-b504b0481d05',
#  270: '7b4c52f3-5086-4cfa-bc95-cf129617efc2',
#  271: 'd0354f84-ffa5-4169-8e82-ef255256a3ac',
#  272: '3632f1cd-5e20-44a3-b13a-a3e2bddae4ae',
#  273: '2f820005-e480-4914-83b8-fab31173250a',
#  274: '47c0e0ae-6879-4b72-992a-3980050bc933',
#  275: '42f8b929-2011-4e14-ab47-4d6da264b823',
#  276: '420cc380-f3b6-4434-9d4b-7b2e2959f438',
#  277: 'c8694014-e3e6-466e-b1c1-b976772dbd7d',
#  278: 'e21f9b6b-90d1-4afb-a135-e38c8c572596',
#  279: '538580c9-7bb5-4ef8-81bc-174ffe20f468',
#  280: 'ea4aef3e-a57e-4d69-8022-c2c1ee3d2067',
#  281: 'e0ef547e-121c-4c2f-ab32-6e22b847c805',
#  282: '56e2411d-3c6b-46b0-a28d-faf3ceb0da84',
#  283: 'ddc2a1a6-4dfa-444a-bc53-090b08fd3175',
#  284: 'e3a3037b-d826-4001-8045-dac13d9fdeea',
#  285: 'e515046c-ae5c-418d-b0c5-1eec3fff7da9',
#  286: 'e5015927-08f0-473f-ac0f-568d5926be18',
#  287: '94618666-1cf7-40a8-ab65-f12c424b1307',
#  288: '6d990fca-aacc-4d95-967b-ecbf7916b333',
#  289: 'a9f08c6d-8148-404b-8b67-af3efef4bf3d',
#  290: 'ba27dfe2-51ff-4ad7-8191-52f1758c576d',
#  291: '2a14d2ff-a472-4578-b431-885b616e89aa',
#  292: 'fda6a134-1d30-43ce-83d5-f7812591a1c2',
#  293: '1b3bf4f1-bd51-4b30-9958-09b50b1c8459',
#  294: '8d57b610-c480-43c3-8536-ee6d95da8418',
#  295: 'a962e193-cd1c-4ea2-b279-0e9314d4debc',
#  296: '38a618ad-fe2a-49f8-bae2-3437421e38ef',
#  297: 'd8a8ccba-19a0-45a4-b604-e5a0499fb40d',
#  298: 'b120a990-58f9-4d93-9861-ff890623bd76',
#  299: 'e907c16b-b8a8-4220-8e09-713f2c46beb2',
#  300: '11e031f7-760d-453c-84e3-e7158a64f6cc',
#  301: 'e3ac9bcb-3f6b-4dbf-acb3-0ef51ca23cf3',
#  302: 'ffc0022d-2902-4225-9168-780e1bb41cf5',
#  303: '599bf935-8e26-4f8f-9061-2b9fadf654da',
#  304: '166bf34f-bfb7-4458-a4b9-6e3ab2a4f360',
#  305: 'aa20728c-7583-4da7-837c-6ca8eec44a3f',
#  306: '31983e9f-b9e9-4a2d-a6b7-2b3f0a13ac91',
#  307: '40e73871-9c78-4ef8-b8aa-cddcf1e6ccaf',
#  308: 'e9548137-b03e-4d9f-95dc-97d955c19053',
#  309: 'af8bb1e0-8be6-4acf-ad01-2e604062103c',
#  310: '0bd57a26-937e-4aad-8b3d-6397a48b65d8',
#  311: '5b8c6bde-78b2-412e-b78c-09785045b56c',
#  312: 'b5a5467e-e6d5-47dc-8597-0c7481cbfec1',
#  313: 'a6c56e8f-638c-4058-bd8c-4db7590cdf38',
#  314: '37f4f651-8b13-4ef9-9027-0abd6457fbb2',
#  315: 'ee5d642d-cc1d-4917-80e2-4d011818838b',
#  316: '34f6fb99-3e93-44c4-8a3e-fce368f4d09e',
#  317: '99fd519d-2614-4590-bd8d-358cbbacc786',
#  318: '3e9973e7-1dd0-4856-89b2-6a880c88cef5',
#  319: 'fbc6e847-159c-4bdf-92a6-a3a9a590f958',
#  320: 'dc969394-4f45-468d-8740-18dcea06e74c',
#  321: '784a5950-861c-4276-8068-67542d260739',
#  322: '9a045e24-ac00-4324-97ff-11fe01999a15',
#  323: 'e15e39db-4bd1-436b-b81f-ba0b4d5aad2b',
#  324: '4b438429-5cee-48ce-9d99-c17a8a7dfcb7',
#  325: '7f55b358-241d-403e-b9df-8e5cda110679',
#  326: '0a237ffc-c278-497f-8dae-ff1032686754',
#  327: '9a9504e5-88de-470e-a3f5-0971b1d9f2af',
#  328: 'dd925f52-a7f2-4a23-89de-a1eec3cb5393',
#  329: 'b3aa300f-6d92-41a1-9e91-10e8fc3a5b77',
#  330: 'a7bfd283-f5ae-4369-8e03-a886cd534e50',
#  331: 'f034c183-410c-4b62-bd67-9d7eada136c0',
#  332: 'b300d40f-81d1-4631-a1e0-e026f1d42361',
#  333: '4d563c5a-7b85-4cad-b1cd-bfae43577122',
#  334: '4567aac8-2a71-4824-be09-b142600a2c70',
#  335: '0ad77dc1-2722-462a-a6bc-76019a4e00f7',
#  336: '2d9214e2-75f1-4aff-9b8f-cd54aedd1101',
#  337: '5a26622e-1a9b-4494-a9e7-76e17927e7b9',
#  338: 'c183472d-b7b2-42d0-b71d-e30354936918',
#  339: '312a2da5-3c50-4fca-b8bf-6c3aca762fa7',
#  340: '86af995a-b20c-4ab0-be66-f8a1d0b038a4',
#  341: 'b427cda5-2f2f-417f-a9f4-6fb5762773c4',
#  342: '2c7a3d7a-b228-450c-9235-028c2274054e',
#  343: '3475c38c-75ac-4c9c-b5d7-f3fca8aecc01',
#  344: '3e53a4b0-0b82-4d09-8374-f76f19f08b99',
#  345: 'da2843bc-36ad-4925-8f65-c2a94e416d0a',
#  346: '98e6ff28-ff3a-4e6e-937f-ac8976b7c97b',
#  347: 'e4be41c9-190f-4586-9542-c93dc56db783',
#  348: 'efcd74e7-0156-48bc-90a3-2f99b57512d6',
#  349: '8a1c8eca-89ae-44f1-b151-1f37bf11e9b9',
#  350: '06bcc621-f900-4233-884e-50ecb97b66f3',
#  351: '7833e06f-4b3d-430c-9b18-62f38ec29662',
#  352: 'eee12fdf-b69c-4b1c-906b-d994e1df58a4',
#  353: '7b2e5970-8ba1-4a63-8ca7-f4b1fa8a609b',
#  354: 'f9ebadf0-da9c-4775-8288-3c1399170732',
#  355: 'd185fa09-30a1-4b01-8303-50d6da24ad2b',
#  356: 'd90add56-d7ef-4020-91ca-e826ce71f84a',
#  357: 'fe4e9f63-6143-4b90-b0b4-634faec64f8a',
#  358: 'ad057b59-a004-4450-b8b7-f25877a4402c',
#  359: 'd7aabfb1-6eca-4b59-ba45-42a42cd9723b',
#  360: '786d0e9f-1284-4d66-a3f8-24870b87bd30',
#  361: '7b2c026a-b98d-4eff-9094-4c3fd33776ca',
#  362: 'd6abb4f4-8670-48c2-9a31-aa868cb5ba4c',
#  363: 'f774614c-9926-4022-a597-f5be8c05f025',
#  364: 'a55683e7-1589-4454-b491-66ab20eee841',
#  365: '267258a6-7573-49ef-8c8b-afefed13588b',
#  366: 'e206bded-5523-4439-bb5f-ff4b2aff8fbb',
#  367: 'b4217c82-30a9-4d2d-8e81-b07345cd2e83',
#  368: '72d7929b-b82f-4159-a8ce-22b9aaebbfa0',
#  369: '052c7a90-bc22-4bb8-8c3f-05bdb5be9fc8',
#  370: '09b96c7f-b5fe-41f9-94d8-3c6c77400418',
#  371: '2debaced-d839-456d-960e-90d0415fb97c',
#  372: 'e0a9ec7a-311d-4cd7-86f1-95774826b8cb',
#  373: '9cf24776-c33a-4838-b520-bc5234ca542d',
#  374: '2d917c41-a83f-4a58-ae9b-e436f1bf5da1',
#  375: 'f0213836-6833-4513-b09c-f3897eaed4ea',
#  376: '1c95767e-3fd3-4eab-a1d6-797b3be5fe75',
#  377: '533a4ab2-65f0-48d0-8386-0ba57cd3af3e',
#  378: 'b3b8d8a7-0394-4c39-9d4c-4fe9109cb972',
#  379: '49bbc4b9-92d9-45f3-9498-30b60b47c948',
#  380: '554c3572-f798-4f9c-92e2-58afb4f02f3b',
#  381: 'b8dc8392-8676-48cc-b59a-2b1d9d361eba',
#  382: 'd3970ead-3278-41aa-b217-4359de483216',
#  383: '2841b141-5677-4a42-9885-ef757a844f72',
#  384: 'eb0c5a02-cc81-46a6-9f71-e2db08be05bd',
#  385: '23717ad5-08ad-4651-83f8-467942c75bd7',
#  386: '9f339181-e3aa-4891-a184-7c4fd88b9320',
#  387: '84572eb3-8c9d-4181-b617-5a27bb4d759b',
#  388: 'd26767bd-eb12-4072-b527-8232d6dc382f',
#  389: '458cdd39-d1b8-49ec-b256-009296ac45b7',
#  390: '1e39b2f0-501e-41fa-bbaf-90769051e5e8',
#  391: '6038ed2b-eacb-4209-b616-dfe8a0300c8a',
#  392: '0e411d1c-5cd3-4ff9-b82e-56f0a38e4eee',
#  393: '540292e8-8ff0-4bb0-8f5b-0e6b1138dc97',
#  394: '5736d377-b954-4dfd-b0bf-74e37922ce6c',
#  395: '50448f33-cc1b-4443-9be7-abfc230711ba',
#  396: '9ad355f0-ae1a-436e-9980-02015406cbec',
#  397: 'e8828c1c-4826-4d6d-924b-0a682362d812',
#  398: 'dc83ddfd-bd8d-4d34-bd92-917a93a171bc',
#  399: '34459c1e-c2ba-48ce-9e85-fabbb787188a',
#  400: 'e3bfed2c-f294-46a8-acba-cdb177f12516',
#  401: 'da2736d6-e288-4392-b899-2335ee0a3c86',
#  402: '79ae87b1-35eb-4361-9999-724d2d71f5db',
#  403: '0c309375-f792-40b2-a219-603fe69729d6',
#  404: '261a2d05-b232-46d8-bae2-418f7b457cea',
#  405: '7d6af518-2477-47ce-9d55-ca45242400b5',
#  406: 'c98cbbe6-ac3b-4595-b894-d8d4e53455f4',
#  407: '5b3830b4-3b71-4236-8818-f8b6efc7d99f',
#  408: 'bd08d297-92e9-4df1-b8c2-326755c0e293',
#  409: 'e74459f4-be64-4293-8ed8-4224151cfbfe',
#  410: '563eae96-be09-4709-b73e-8a746faba07b',
#  411: 'bf6d9033-bfef-4cdb-b7e9-2596546b1583',
#  412: 'f732ac83-1948-40f1-a47b-ba96a9206e20',
#  413: 'ecf3c1c2-f844-43b7-a1bb-8ea654e81c5a',
#  414: '55515ba5-ad61-45fb-bf7f-85b228494085',
#  415: '0d6963c2-800f-4a08-9f16-c55a39d828d5',
#  416: '1448f718-7bab-4744-8ddc-cfbf34760f14',
#  417: '72e4403e-a046-4b1b-847c-77bbca56cb98',
#  418: '804d2ce0-13bf-463a-ab07-fb1c38567f40',
#  419: 'e0cafff5-37b0-4f41-8d25-abe2729775ee',
#  420: 'f8979155-6c24-43d0-98a2-69bf066c5c0f',
#  421: '350dbd85-6290-40b8-80fc-b3340a86e33b',
#  422: 'aaffe7af-8f9c-4504-956f-fb337d9e4a6a',
#  423: 'd5a23d65-de1e-4145-815d-501ae1793132',
#  424: '39defad2-8df7-4073-9a48-4043c7551796',
#  425: '15a2775a-d8fe-4198-ac8a-8256ed0fa0f5',
#  426: '13f797d6-92b7-4abe-a5ee-875d0cb43365',
#  427: '71482d30-01a6-4023-b4fa-04c4229e19a6',
#  428: '1aeaac61-67f7-49de-baa5-0207a64d9251',
#  429: '9c95a268-adaf-48c2-9fa6-10056f728b19',
#  430: '4af3d57f-5e2d-4dd3-8650-6a0b167649a3',
#  431: '1fe80f2b-cc69-4f08-8f54-30e1145ea3fd',
#  432: '52e4f27a-2f63-45bc-8207-e317e43fbcfa',
#  433: '45702e8b-f8c6-4e50-bd26-0102ad6bfe84',
#  434: 'e62127e0-2d67-4153-acb4-bbd5032d5a55',
#  435: '33e98cd0-39d3-4138-928b-9f6e0043277f',
#  436: '4c26747c-1753-432a-9ea3-16404a9288fa',
#  437: 'cdbe30ea-7ccf-4dd3-9231-f9f22b8747f4',
#  438: 'ce01dc68-75fa-4b1c-bdb4-790bb4b79f67',
#  439: '3cd0f840-91b7-4f05-a713-6427637a4c63',
#  440: 'a45c326f-1680-4f6e-b133-898d5939b47a',
#  441: '0bb5f4e4-c1c6-4aca-8487-dbafa3b3d744',
#  442: '42fe2da8-b1f7-4762-8f87-bbcefdd2d64d',
#  443: 'ddb4d429-31ea-476c-9901-23477dc64ed7',
#  444: 'f9ee681f-4593-4c5f-adb6-065108c6bd7d',
#  445: '6a5995e4-d970-4ebf-a715-2a1e77ef13a2',
#  446: '0c2764b4-74ab-4157-b302-8ddf32e9ef92',
#  447: 'd7fac780-9ed9-4eba-aa2e-22b6c0ce4007',
#  448: '8da57f7a-1eab-4517-a12f-d6e1eb4a3e46',
#  449: 'be70c69c-f85e-4bc4-ab81-c48a6629953e',
#  450: 'f82c7c20-6325-4ade-948d-4164a35c971b',
#  451: 'aabb3969-972e-4220-a970-7871dce8e936',
#  452: '8175e4aa-48e0-418c-bc75-10f7d8886270',
#  453: 'ab7d790a-b2d9-4489-9d0b-17ab69427787',
#  454: '37f36b73-9f5e-4c09-841c-24fa6adaf139',
#  455: 'f2515ebd-5dcf-4017-832c-a8edff1d9a90',
#  456: 'a5f6ff27-f03c-45f3-9211-2e3b3155942c',
#  457: 'c86f75dc-198e-4636-a095-40da8d0a1f12',
#  458: '00d90aba-7ff7-4ea2-9cad-a9aa7837a134',
#  459: 'be100dda-37e6-492f-a6b1-50b0d7e1b6d1',
#  460: '517b2f9f-0833-4fde-9496-c319825c4589',
#  461: '01e22a15-7fb4-418d-9270-ef655c242a23',
#  462: '28a8ea66-3bc8-4bfc-a5bf-974aaa272d94',
#  463: '7ddb9cff-9ef8-45ad-979e-5de660037a94',
#  464: '9d7707fe-7dec-44bf-a7b1-e52959d6da60',
#  465: 'a4d92d55-bd86-4222-8c13-ac5e011cb54f',
#  466: '2e29bf5b-21fa-4e41-9b03-1be657cb2085',
#  467: 'ea838340-548b-4622-8a45-761bb4e1cd66',
#  468: 'ecbd6a80-3a50-4bac-9dd9-b28a9dab1edb',
#  469: '92c72335-3b30-42a1-9bb5-0b184f99e1c3',
#  470: '31263456-1785-45df-b919-c6f35ed7361c',
#  471: 'ff749cfd-b673-4265-b7af-f9990896dec5',
#  472: '7a92b384-2024-4257-a8c5-629a35e0fff1',
#  473: '22722c9d-9961-4ad4-a1fb-1cd69a8732a3',
#  474: '1e7cce11-425c-4a89-90c6-2e44c50c480b',
#  475: '70e61e6d-1073-4c24-8e15-e81e15060dd2',
#  476: '008959a8-ff84-4583-9fed-cfb53fdf7ec8',
#  477: 'eadd804a-5866-434a-a691-39c66c67fdb7',
#  478: '6c24e9e4-d0b9-45fd-89e2-dbd474e20107',
#  479: '48454e7f-6b51-40b7-88f5-e74b9f662049',
#  480: '7a4fcd41-6709-4145-97d3-1196805ec234',
#  481: '6edb9356-653d-445b-9cd7-edeb11d18839',
#  482: '0ec35ed8-9d3e-4e8c-a2d8-eb821e291407',
#  483: '5738dfc6-3be3-4eb8-8e9f-6bbcf986809c',
#  484: 'd99e3bcf-cfc9-48c6-94bb-a57b084ad0e6',
#  485: 'e19cf692-da81-46c6-bad0-2c7380a73234',
#  486: 'f2896e80-89a0-4ac5-8141-053999ca0bd6',
#  487: '585ed2d4-1b63-4638-9d4c-0ebcf5ee4f81',
#  488: '51ae1700-a935-4743-bc29-a4be040b1b02',
#  489: '36a85062-5f5d-433f-b543-4ecf053510b1',
#  490: 'd5c0a1fb-c336-4dd3-97d8-37c35061ea75',
#  491: 'eca01c30-364b-43fb-a6f1-0bcce6e84e2b',
#  492: '3ca98855-b14b-4a1a-9bd8-b96f588eb342',
#  493: 'b701b087-8b7c-4b06-9214-3c9d8e618f5c',
#  494: '2167ac42-2ee2-47d3-a84d-9ee36dab0c22',
#  495: '9575fcd1-fafb-41da-a5cb-03b1050b7e1d',
#  496: '66740d4b-87fe-46d4-be8f-3ed9b35c1e64',
#  497: '5e312b6e-8e39-4d18-8799-a71fa0c171aa',
#  498: '1ee225d6-e3ce-4e67-9935-917e246fbb49',
#  499: 'f76c08a2-2e8d-4f0f-8cc9-6d6a24849861',
#  500: '7fa6438b-8524-4f7e-9cd0-b7d1eb2dbc87',
#  501: '91802e04-c172-462e-9ba6-bbb5c7e56726',
#  502: 'd79d5bc8-c9c3-4fdb-82dc-e8f2a2f2e76f',
#  503: 'b989aeed-2721-4be9-99bc-999aba6cbeb8',
#  504: 'b0467c1a-7980-4796-8b1d-bd16d7ed8433',
#  505: '76725e20-d8dc-4f13-ae55-1d74c482db69',
#  506: '62fe8bbe-d670-4990-80eb-4c30a0aa170c',
#  507: '4adab03c-53bf-4bb4-bbf8-aeca71339514',
#  508: 'e5260004-ebbb-4a9b-b4d1-8023d27097e2',
#  509: '71be2e60-5849-41c8-a36e-ae81ba503dad',
#  510: '44c7a720-5543-4b3f-998d-3d802126e165',
#  511: 'fd02b36c-2dd1-4eef-ac25-a6e5d99b6f08',
#  512: '1a628967-f30f-455f-a265-e705d93fa3c2',
#  513: '2e5de2a8-d479-4805-a234-16e82b65072b',
#  514: '2dc855df-39ba-45bc-bc5c-695ef297e5a0',
#  515: 'dff03a3f-38b9-4e4d-81aa-4cb7d0697517',
#  516: 'aa7bccd1-4596-4f58-a694-57fba044f0eb',
#  517: 'df11a098-06cd-44f1-91fa-f0ab3f87f456',
#  518: 'a35a59dc-f3fc-4c43-a5f0-c5706adace20',
#  519: '0c8e59c5-ba19-474d-b823-ed50859c9405',
#  520: '5947ae6e-1e7f-4a60-9efd-6c94b0c15e08',
#  521: 'b36603b3-e867-4efb-a117-d5cdbec044ac',
#  522: '1c1dec0e-ee5a-4011-b32b-0dec700719fd',
#  523: '64d6e817-2002-49e1-866f-2b3bff84ac78',
#  524: '209cee18-f6ba-491b-b0bc-88a368640508',
#  525: '408e50fb-7149-43a1-ae06-30f9e3c0fa6a',
#  526: '60e173b0-bb01-47f2-8d6a-97cc963aa990',
#  527: 'b973cfce-0720-40a4-903a-eaf7a911a876',
#  528: 'b05a52b4-35f8-48b5-aabf-3d62a777c74c',
#  529: '517cf403-f90e-4081-9968-4e1d8e6337e3',
#  530: 'fe20cf81-dc2f-41c3-9dd0-e7773be9898a',
#  531: '70779729-ddbf-4132-a761-007a99b4b91a',
#  532: 'e4b8e9d8-1587-458c-8a4f-12d68a97237a',
#  533: 'e8a1c10e-c2f9-4faf-b780-b6989c910530',
#  534: '40fb37fd-6f60-4365-b63d-e950c33b8991',
#  535: '7e681370-7472-4b1a-a058-201276c29ae8',
#  536: 'b70e24ac-6d60-4715-9dda-0fae9959d873',
#  537: '7b10ae7d-8ab9-4dbd-9948-8c310eb939b1',
#  538: '3c859192-1755-4784-b411-63e7ded63499',
#  539: 'd984b42b-ff3f-46c0-b85d-d662503d4caa',
#  540: '0b5eb62b-cc00-40c8-96e6-3e02135c5a15',
#  541: 'd9786e7f-bea8-4f1e-b2b3-4db4e645d203',
#  542: 'ffee7236-bf0f-4de4-975c-414162e0b0a4',
#  543: '060492e2-ee04-40c3-a68a-ea7b024f00c8',
#  544: 'bddde0e6-1d3d-4151-8f7c-5bb7a1a23e1d',
#  545: '7d4cf35a-0f3f-43c7-9d5d-8abc19343555',
#  546: 'd2f450c0-e2fc-4edb-bb81-baad80073ff1',
#  547: '74498c68-7db0-4ebd-bad8-d572062f1c98',
#  548: '3af859c9-3193-4cd2-9565-d805fc5797c9',
#  549: 'ae5e408c-8484-4a50-ba3b-1da9cc6c8c47',
#  550: '635925ec-80b5-4400-aaae-21d994405296',
#  551: '970a8858-7ea2-4241-a9f7-845ec16c5015',
#  552: '92a1c207-e010-4d5b-aef1-e9f2cd22187d',
#  553: '0b450778-e37c-4911-9883-f85635ecdb98',
#  554: 'd3f49d9b-7cf1-4cea-9bd2-2f19fa1a36fd',
#  555: '276ca4cb-2e99-4f69-afda-56d620f477ef',
#  556: '8ff2734a-4311-482e-9d64-4f59fa95eb43',
#  557: '05e36791-9804-4ed0-8edf-e6ab1361aaed',
#  558: '3d3b32d3-3e0e-44b5-8504-431b2a6a9650',
#  559: '9adc9d28-05d2-4887-8d43-d40fb0570270',
#  560: 'c95bee96-c8ef-482b-9201-dbe3f3b948e4',
#  561: '0b1d1c3d-fa8f-42bb-a95d-c21903b0b4ea',
#  562: 'bd7c88cf-0664-4b0f-aba0-794ed49e353c',
#  563: '64aba817-5f92-4993-bdd5-d743bfffe896',
#  564: 'fac3810d-0de5-4faa-9841-62bced426c72',
#  565: '0f659bd2-3ea1-453a-8820-a1cfa8dc2fdc',
#  566: 'b75f22b7-0136-4713-b1d7-e5720605df59',
#  567: '16f2282e-c482-4425-a0d2-b91ce266a483',
#  568: 'b140871e-cb66-4e41-af01-bdfa32dae795',
#  569: '26d11d05-c467-4b92-a72b-b8f6a1eed39c',
#  570: 'd1d53651-8535-4a8d-a49e-380443ea4837',
#  571: 'e28a20a8-5899-4d90-86b0-4a3a9aa5f057',
#  572: '4432eae0-6976-40e5-97a3-e349ca179369',
#  573: '4c8bcc68-c61e-470b-8ac0-75fec661871b',
#  574: '9e8655e3-550a-495e-aae2-1880da9d52df',
#  575: 'a977a0ce-e517-4532-8764-43b54598ff7e',
#  576: '0b2fb511-761c-466d-aec6-f2335a6d24b4',
#  577: '853096fe-8eb1-4a5a-80f7-328046eb712e',
#  578: '00fdc0bd-cd3f-4fc5-b3ab-9aa20d9b082e',
#  579: '016031f6-5280-424a-977a-dd45af1c0b98',
#  580: '6c284ae2-7b9a-4f51-b899-088b14eed609',
#  581: '08556ed7-7476-438b-a10b-7898057831dd',
#  582: '147895c8-a016-4a19-94d0-2a74c23372e8',
#  583: 'e23557bc-3a62-454d-a47e-d8f30fcb8f70',
#  584: '25284b66-1a80-48cd-ac94-8db5fba889e8',
#  585: '8ec8f777-3680-4230-b612-0942b3a7c2d5',
#  586: 'a561d520-5a95-432c-a905-c270b36a33b2',
#  587: '29cf2d2c-4348-456c-8a4e-d294303bad63',
#  588: '7e124a22-f085-4a29-9d3e-7501012327e2',
#  589: '0a2e6fdc-f0cd-4c28-be82-2dd249f492c1',
#  590: '40ed62ad-ee16-4a05-8c7b-fdbed1d54cda',
#  591: '4cc30ce2-f778-4422-9e0a-401a5814dbcc',
#  592: '92c09302-526f-410d-83a7-6580769c404d',
#  593: 'fa61587c-595d-4250-a39d-294ae811495c',
#  594: 'bdae9778-9dad-4124-a611-504ff57c9abf',
#  595: '246d6e20-26a9-4a57-8af5-bb498f0bd092',
#  596: '0570041c-bca9-407f-a549-5bd782d10f63',
#  597: '5a4c6281-3617-4b7b-8310-de296af5fe6e',
#  598: 'd17f3c46-6f7a-4c25-b8da-da76616ea501',
#  599: 'ca5b62f6-93d1-4b55-af8a-f209cb6f9c90',
#  600: '0daacd84-a8ca-4a80-89ed-b03d4c52442f',
#  601: 'e92410d2-5f2b-488b-9e96-bf4f253f68b3',
#  602: '0b04f8f9-6be0-4876-8546-8c0f4eb5201f',
#  603: '7da11539-7cfb-4c0d-84ca-84bdf595e17b',
#  604: '419775c1-6207-44ee-8e99-e4783b8373b1',
#  605: 'f12a0052-fc4d-4f0f-a402-d5125d51c23f',
#  606: '48b3a51f-ee10-40a1-aee7-5b06c4aae9d3',
#  607: '8b783274-17f7-4fcd-be06-f2efc307c75c',
#  608: '1d670268-4270-49f1-a364-86a234391dda',
#  609: 'ebc8dd50-3ac7-4cc9-9d38-0666a6501f8e',
#  610: 'e7ffb135-7711-41d0-8bd7-018215dd2f0b',
#  611: '4d8dd630-ff5d-4f3a-937a-dcdc381e95db',
#  612: '162398b9-dc3b-493b-a661-f9c80c44f4f7',
#  613: '26ca6faf-36fe-4bbe-a3a9-491ab8931eeb',
#  614: '3f7cef90-ef35-47f8-8feb-d03e9c75a46d',
#  615: '1b8114d5-58fa-4ecb-9d0a-459afb62055a',
#  616: 'c7c7dbfa-6f0a-4825-adc3-aa38f642166c',
#  617: 'b9bfe9f4-84bd-42c3-aec6-25f43fdd852a',
#  618: '7229b48b-d540-45ef-9ca0-ffca006ba7f8',
#  619: 'ffc963a7-d0ad-4b47-a12a-e952a2ca032b',
#  620: 'bc9980cd-27fd-4e1b-bb0d-8285382f0f66',
#  621: 'b62d2c77-5725-41c0-8bbd-0c98d2de8e4e',
#  622: 'c7140420-e8e0-4be0-8c51-1a174afdbfa9',
#  623: 'd2155981-8051-48cf-b066-351a2d47bee6',
#  624: '53cfb490-4c6c-4927-b70e-347d1b516195',
#  625: 'f18a126b-a7b0-47f9-adce-a01db05df7db',
#  626: '948829fb-36db-4905-bab4-a04442766e04',
#  627: 'cd541011-9241-42d3-b6a2-8d67323d43fa',
#  628: '561f984c-f742-43e9-97ac-928bcadb4342',
#  629: '6f4fcfa4-d1f8-4a76-8082-423fb49890f2',
#  630: 'ccaa043d-3bbf-4424-8bb9-5d06ce01df31',
#  631: '834ac266-4049-493a-92f9-982c513fb51b',
#  632: '930563d4-09b6-4559-9fe3-133812f0a96b',
#  633: '0a5ed50b-657f-4730-9c30-c4f9974ff2a8',
#  634: '3d90a40c-ff28-418a-ae8d-3fd61448ba0d',
#  635: '17dff0b8-b2f9-4277-98b9-59a9ca2e5dbc',
#  636: 'cd0b85be-b36e-4a3d-afc8-1ceaa01cf0a1',
#  637: '0066190c-fe8d-43b5-8596-ce9595a16d6f',
#  638: '7aa3932b-8ba2-4bde-847c-537fb6b20ca4',
#  639: '01c677fb-8190-4227-903c-917ccd7ea1d3',
#  640: 'e94a2172-cdad-4ed6-9421-e04b6c7f33c8',
#  641: 'a6193d3c-f410-470c-8c9f-6286727fef52',
#  642: '1f90e436-9705-41e9-9713-d3f8e1f96807',
#  643: '3790527d-0b9a-48e6-a2b0-acabfb5f72e1',
#  644: '15157433-ad6f-4942-ab04-43110f6f619d',
#  645: '714fdc32-cd76-450f-a568-c357aeff67ef',
#  646: '56ce1b2d-560b-41ba-a848-7952ff6f1325',
#  647: 'a7936f4a-b209-4a8f-a840-0e5712fb3334',
#  648: 'd402e4d0-b1b5-4ec9-be35-329e86c68d04',
#  649: 'c53ecc5c-41c9-4692-b5ad-0463351dcacd',
#  650: '60073dda-c421-4bfd-93bd-760a75113e8e',
#  651: 'aa7ea367-c35c-4dff-90c1-2590bb543d52',
#  652: '5ba48e50-1606-459f-bcdd-19475b9ba2b8',
#  653: 'f337b6fa-6a1b-4caa-8750-757d8bd0b35c',
#  654: '9cce282d-9354-45bd-9be3-53fcddf63448',
#  655: '43039146-14fb-41fc-b331-c3b18ef79154',
#  656: 'e918b831-6f7c-4498-9b9e-5e8213718518',
#  657: 'b91bcd41-f40b-44d8-9f97-a8686bd32bc5',
#  658: '597328a8-bf6c-472b-a5b1-6d5da89adcb4',
#  659: 'd4355b78-e9f1-48cb-a5ac-1db50c69c614',
#  660: '909f9e93-3cbc-466e-853d-a1a2dd4eb3e0',
#  661: 'cfd249f6-b924-4519-9783-1ba9c282b692',
#  662: '807a1042-2326-419a-bc7d-c66dc79f4370',
#  663: '89936f4f-c67e-4308-824e-8146b394e4bc',
#  664: '8ea7086d-4a7f-4b08-a75d-e7a9e9926c73',
#  665: '50a5faaf-0934-4b17-8256-c752e366daf0',
#  666: 'a7e1fb42-64de-4469-97bb-a853a2247d03',
#  667: 'eb5f95cf-e868-47dd-a846-b8b578c60d28',
#  668: '29bf7b78-3ff4-49f9-bd7c-7b06c917d30b',
#  669: '0ec31de5-bffa-4a03-85c0-b873651e8874',
#  670: '1dd234c0-921b-4057-a924-cb09f33fe820',
#  671: 'a8012ab2-e28e-4542-838a-a7d3d958c633',
#  672: '20729abb-217e-439a-bd33-4b6651c74e16',
#  673: '67171fb8-9a21-439d-afd7-fb0a7124890b',
#  674: 'b2150c17-0ddf-4687-8b0d-e7b94d784767',
#  675: 'eae0203c-bccc-4a75-8360-a566db92117e',
#  676: '7188111e-78e1-41f9-9725-8e2a725fb1d4',
#  677: 'c86ee954-6a6e-4397-a957-2c7aa7a84b5a',
#  678: '9963bdef-2728-4576-8ab9-6ba84759eab7',
#  679: '5edc6016-a1ec-43e6-9281-b70e5ea33c43',
#  680: 'dac6c103-df4a-42e0-9afa-577676628042',
#  681: 'ff6dbd74-6b6c-4137-a62b-ab2e73ac1089',
#  682: '665a2211-9136-45a6-8a6b-8bae1125963f',
#  683: '0ef83cba-f010-4a5f-a46e-82a2a94e2aea',
#  684: '07ec1ec1-50d7-4701-8d63-cdcc3bec8dc3',
#  685: 'ec8b449a-e966-4176-aca3-6eb13750d7ef',
#  686: 'e8241b40-93a2-4094-b549-20b9340f6e54',
#  687: '9a8e036e-5831-4171-b3d4-2c2872d7615c',
#  688: '0b1675cf-9e31-414e-aefa-c41cb875dd7c',
#  689: 'f7b36efb-fafe-453b-89c2-baec6389cc8d',
#  690: '7c902d3a-07e9-4b80-9e48-f1cce7fbc321',
#  691: 'a4853443-d2c0-4dc5-9b90-6758571819b9',
#  692: '056985d0-6e0d-45c6-b089-fbf1ab5371f6',
#  693: '0d189c37-439f-433a-9aa0-bf50a62294f3',
#  694: '1917ef3b-080d-4464-8d23-f98e6ef555c2',
#  695: 'c91529c8-db89-46bd-ae8e-4be698382f11',
#  696: '05ed318f-b2ea-4071-8426-9dddd91189ef',
#  697: '78c78d2d-8033-420b-a247-23b022c58784',
#  698: '4425fd4c-4afe-4cf0-9414-5a77b9f78651',
#  699: '0addd713-c047-4608-ab49-dfc2c099c654',
#  700: '539ec413-f260-448a-b60a-c772c010f1cd',
#  701: '62e378d0-e1b3-4dce-857d-fc7c8a06ccae',
#  702: 'd0358516-90c5-47b9-ac23-f589bfe7e314',
#  703: '09296322-cf66-40a3-a67b-f7f0767225c8',
#  704: '526e9916-c5d0-4a59-9d9a-630b44b29906',
#  705: '0116d083-2836-4006-95d2-7c2cc3bd11d8',
#  706: 'eb56351f-5053-44e1-bb4a-ff5eaeef24ae',
#  707: '9cd2b9f4-8436-4c78-9591-8604772ef3e0',
#  708: '1142909a-2000-41f5-a255-0b357ee9e9c6',
#  709: '0ce773cd-b302-4fc8-a03f-67585d44e25a',
#  710: '888099ec-1fdc-4940-93b8-792eb258698d',
#  711: '3ec4fe08-182b-4041-9529-e045aea708fc',
#  712: 'f2a3da3f-bde9-4231-99b1-ac7ec13badbe',
#  713: '11030ba9-6ccb-42b8-9373-88b93e664f4c',
#  714: '9c1b9adf-c4cb-4453-bf47-27c3ba072e6a',
#  715: '1ea2887b-ae80-4864-88da-ee608f5d71d5',
#  716: '63bd2db4-e5c4-471e-871e-f29fc542f665',
#  717: '4a8b6cbd-d304-4712-aa4a-3b8b3c9bf3ff',
#  718: '04ac1cd9-7506-4cef-8ac6-2982ab8e8bcb',
#  719: '68d845b0-2713-46c1-ba8d-7f9fbc6dd1bc',
#  720: '1c77dd9e-a157-4d04-a9bd-d9f5c187b199',
#  721: '69595acb-4ec1-4a4c-9e77-763c2ce28758',
#  722: '70671d47-5c33-42d3-9392-5346d24c9537',
#  723: '61d46892-8dfd-4a67-ac30-d4e55b3fd3ad',
#  724: '05f200c8-b286-49c7-a9a6-10f964461b7a',
#  725: 'ae95ad29-cd65-419d-8dbb-5a52c8d96c6d',
#  726: '64a3b739-4dc8-4397-8f80-c7c539262245',
#  727: '1beec86f-282a-45f2-b2a8-b9a4d4b944a5',
#  728: '2671762f-b373-4880-8fad-9b4a13e466f6',
#  729: '38f69f97-34cc-46b7-a7f3-4fd1e9fe66a2',
#  730: '9178d708-9f6f-4d28-9200-df9e2a583c3a',
#  731: '22e79b1a-55bc-4561-94da-bad00f930c1d',
#  732: 'ca323196-4eb1-4508-a2eb-e0aec19abac5',
#  733: '79b5e272-6cf6-440c-a5fd-9c9489fe0fe2',
#  734: '3dbf9006-8767-4298-800c-1669e5a242c5',
#  735: 'eb3d49b9-4e08-46c7-9870-789531676b6d',
#  736: 'da55ae05-7e6c-4b62-aaee-e82c421a3fe3',
#  737: '15a06ef8-3e9f-40d9-9168-7e8698cd1d9d',
#  738: '2927fce2-b3e4-45ba-b5a8-a78d911017fd',
#  739: '1befeb11-5d8d-4e46-9518-19589af72621',
#  740: '8ab1f441-ded2-4bb1-891a-791d16c15a16',
#  741: 'b8c942b4-4865-4e85-9dc8-7186133b45f0',
#  742: 'ea478b21-9d26-4818-8511-9cb2a5f95588',
#  743: 'd7df8ee8-d3cd-4c48-af4f-bac04ab36aeb',
#  744: '2d84ce89-e645-4afb-91cd-a23a76d02be3',
#  745: '33c6e8c3-763e-4ce3-abfa-a697469e4ffe',
#  746: '3df7a2b6-92d9-420f-bf39-40afa0ed0184',
#  747: 'a2189064-1ea3-468a-9900-95dd42a91c74',
#  748: '6c96fd48-b1db-4b57-92b2-d6aaf820dd86',
#  749: 'b806bd96-82fb-4162-9b51-c7755da43087',
#  750: '07436018-a1fa-4af2-ae70-8143e3fe97f6',
#  751: '74e59e36-6154-45c0-8296-f3d940c03b4e',
#  752: 'c29fdd0d-814c-417a-b9a6-9106cf27bf26',
#  753: '4599e864-35c5-4f78-878c-61a25f37d766',
#  754: 'd5875ed5-7e44-41d8-a1c4-d10dc495e305',
#  755: 'c8e8619c-1fdd-4d35-aee4-37b290a36781',
#  756: '757bf4c5-c258-4021-8b05-138decc1128b',
#  757: '14d2e3fa-f576-4398-86e2-c1b393ad5d04',
#  758: 'ca78b482-e676-4f34-b09d-3243fc05a6cd',
#  759: '8c342d70-9e7a-4d67-bb95-0b84fa04606c',
#  760: '55d133da-4843-43f5-87d7-a2f539f331c3',
#  761: '1c3f05e6-f13a-46ff-8353-b836e1bb5598',
#  762: '539f607e-7ef3-4c80-b1a7-cd2a56f92178',
#  763: 'd2eee60f-9bdf-40d7-9a10-63b46712fa55',
#  764: '9df2eb94-6743-4625-9de8-6b4aadd788a8',
#  765: '11826f84-fb4e-4e83-8a3f-f6a2750b21d1',
#  766: '055996a0-d3d4-406f-bb87-881de7216efd',
#  767: '6a61288d-c15d-4a02-bef7-091814c5e79e',
#  768: '06b485a8-079a-4d4c-a895-fbdcf385b6f8',
#  769: 'ee1375af-abc8-4aea-a371-759233d928d4',
#  770: 'b2435b7e-0af3-469a-bb86-164c494f93af',
#  771: '9f5dda84-458b-42c2-96a8-72b18e8ab227',
#  772: '469cb0e2-a709-4094-9ae6-861abb00b814',
#  773: '6f7ed8d5-db8f-46ad-ba99-a881b8da9f71',
#  774: '3f26fe54-df4d-47f2-8e20-2ea0475a50da',
#  775: 'd1cc0348-03a3-4e23-834b-96f4ac48eef6',
#  776: 'eea1f9bb-cb90-47a8-9670-d27b61e4cf91',
#  777: '7f60d827-9091-418b-ae23-e05e73922d08',
#  778: '474a0b32-2242-46ef-8adc-07253e8d5323',
#  779: '30841285-063c-44e0-a017-669d262243fa',
#  780: 'd48ec0ab-90b0-4a86-ab66-15bb431ca269',
#  781: 'fd471c5d-1b39-4fd9-858f-d17b1b68ad19',
#  782: '14ea901d-021f-4bc3-bf39-150c1aee426f',
#  783: 'a196cd9a-b44b-4d95-9a7a-411893f64406',
#  784: '655a5606-7f2a-4270-b285-21e738ecbb91',
#  785: '55c5e553-97eb-4ce5-89de-3f9be3aa7d80',
#  786: 'e3816503-3c6f-443c-85dd-ea77ffcfd5c3',
#  787: 'd184f7d3-85c5-4825-b8b4-73be35dc58ed',
#  788: '4efc47df-6e2d-40c3-9293-4d58f82ec438',
#  789: '637cf3dc-42ca-4254-9ff2-d07cfe2c5eba',
#  790: '961c8da8-10a3-4fa0-aa89-4256c1439861',
#  791: 'd7286fb9-328d-4c92-9544-5d2147058a78',
#  792: '4531f43b-7edb-477a-ac1c-77d2938c67f6',
#  793: 'baa07f80-6fe1-48b5-b6a0-285e079b97bb',
#  794: '3576ace0-64e1-463e-94cd-7f9bbb6c94fc',
#  795: '95ff4f14-bf65-4652-83cf-523d5184bb09',
#  796: 'c3155c8e-739f-4421-a13f-423b3688ef12',
#  797: '8af04af0-2c46-470d-b18b-a2b2799ad865',
#  798: 'd71575a1-1d2a-4de9-ae88-259b6f687c18',
#  799: 'cc6084b6-724e-4294-87a5-a7884868515c',
#  800: '70762b9d-0aa9-4be2-b93e-398174fcef84',
#  801: '9ea198b4-ab7f-4570-983c-4403c88e08e4',
#  802: 'c3b51fcb-9699-4dd3-a56a-a61a0b664e9d',
#  803: '486b1aea-28f9-4df6-b6fa-99f6a6757574',
#  804: 'cd95f7b0-5d27-42ab-b65e-57b544865458',
#  805: '6957f85c-966c-4f0f-bad6-8b4f8890cac5',
#  806: 'a08a41d5-4995-4178-86af-bab9d8720316',
#  807: '852bfa2e-03fb-425c-b0ad-b1ebe274579a',
#  808: '0377610c-b065-4b7c-a9ae-83291e65673b',
#  809: '383f5462-eaf6-4b79-ab72-e2281b7fbfb7',
#  810: 'dd777ed6-11e3-46a9-ba24-410f7a75ed65',
#  811: '66273ef0-2e3f-4347-b5df-ea58ba364a3b',
#  812: '1f44ace4-7e40-4fdc-a914-97163efd3ba9',
#  813: 'a8d9ef89-edb9-4ad4-8bd1-6c0b2bd31b5d',
#  814: '5a5b93ae-f238-445a-a2dc-cf138750dbcb',
#  815: '526eb69b-6683-4cfd-bf80-c79af11059c8',
#  816: '1a3e59de-997c-480b-bac4-102aaf5caba2',
#  817: 'fc6ed927-75ce-4c9c-ac5d-bf0bea237098',
#  818: 'f7f0eb10-1cec-4291-b652-2a6543185b6b',
#  819: '975d51f8-97e0-4392-981f-c7106f630c0c',
#  820: 'bedaaddb-33af-4b52-9053-85d0189371f4',
#  821: '35f999e3-1130-49ea-a5da-cca0e7f003b4',
#  822: '84885821-28f3-4ae2-8296-ddb45d2c95a6',
#  823: '0cad4517-2348-410a-b631-99b64fdb5815',
#  824: '34c32569-a4a6-4b27-8dac-94e4e8c91925',
#  825: '576a9408-0702-48d2-83bb-a59d62509a96',
#  826: 'ac22b681-3283-4af3-b01c-e2fd81d92e5c',
#  827: '5b20f93b-c138-4a96-a7d3-9f6b96ab86c7',
#  828: 'a4879430-5622-4fb4-b17a-710ca5c85f8e',
#  829: '676b22a1-5a2d-4912-9a12-645326e532af',
#  830: '032e043f-42f9-49c9-9ed7-4684d2851122',
#  831: '2b5a6a69-a548-4d7b-8154-f3bffd3cae4a',
#  832: '9e31fc89-b17f-4396-90fe-f0ffed5a77ad',
#  833: '17221b3c-6112-445e-9a63-99e250f3e668',
#  834: 'f602fb3d-1160-4c0a-81c7-0c7066f1897c',
#  835: '6ec48bcb-46db-48d3-bca1-0679f750e706',
#  836: '1054d162-63b4-4c28-98dd-bb4ba3314dea',
#  837: 'af039a6e-1045-4485-9410-21061247e7b0',
#  838: '7a3ef3d0-69bc-4934-9772-812d65d689b4',
#  839: '7345ed41-8f25-4029-9759-f698d141b9f2',
#  840: '489606cf-a3b6-457b-a32c-1d4729cb1768',
#  841: '47f10361-c447-43ff-bfee-12b75d6feae7',
#  842: '2385187c-5afa-4826-9db6-92c94fb041ad',
#  843: 'fef9f78e-7b03-4f7a-a124-8c83d145bef6',
#  844: '64e95385-5549-462d-97de-9342281cb932',
#  845: '4e3e4cf9-84a4-4057-ad2c-e07e94808b0e',
#  846: 'f76dd76e-3f3e-47d8-86c4-5a6f9ef81afa',
#  847: 'bc0051ef-d655-48f6-8ef1-8bbcb9636130',
#  848: 'd55098b7-d1b5-4f08-af1e-4828e58c7b8e',
#  849: '317a06cd-ce6e-4f0f-b70a-04d05acaefa1',
#  850: '8a66d2dc-7a26-4ba3-b1e3-6bbc740fdb9f',
#  851: '058d5231-fa71-469c-9353-367ab31d9a17',
#  852: '5b9296db-58c8-40eb-ad2a-716c472adbf4',
#  853: 'cdc152dd-012b-4989-b5a8-e5fb45273bf0',
#  854: 'a33f7841-9288-4f5f-94b5-d1d84b2ef3fc',
#  855: '0a44eec4-f79c-4e3b-b789-76c53f603ddd',
#  856: '607a6ef4-4b64-4205-a7c7-0705149ad903',
#  857: '9ebc816f-c1b4-40f0-99ec-8ad78c99b2e2',
#  858: '3b43947a-4eee-4ed4-b138-93c257598b9f',
#  859: '6a5a9c51-5df3-4f08-b7e7-0319e9cc0f0a',
#  860: 'b9b8f26d-0a6e-4ca5-90e7-87019ae5bb90',
#  861: 'a3673fc3-1a6e-4657-9581-746ecfeee272',
#  862: 'd0d00a99-72a3-4544-8b10-05d7c73444a0',
#  863: '739e163e-0591-4ede-b68c-a8bbe8e6c2f4',
#  864: 'd7589d1e-e88f-47c1-99f3-8751b39c82b8',
#  865: '3b771f39-f146-4c4a-91ed-3be0054c792f',
#  866: '8eb2c9eb-66a7-4755-a44d-c450eca47837',
#  867: '0ea20992-7085-49ac-b711-36e1e2def5c7',
#  868: '6879e994-1643-4c21-a1ce-4006de98e5ce',
#  869: '311ba5c5-590d-4363-b1ec-993a607f4db0',
#  870: 'efeeeec7-624f-40e0-ba35-0b50ae0205e6',
#  871: '796eac24-0a61-4a2a-91e7-eba68f8dc874',
#  872: '433edbb3-b7e9-48fa-ab7e-7eac4b396506',
#  873: '6a837b38-6d7c-4efb-ab78-afd79e3cc447',
#  874: 'ae56f079-7ecb-4540-b16c-f1a336b07ab8',
#  875: 'fd51eaf0-b0d1-4903-8137-a432ec9aa5ff',
#  876: 'f3e8d797-0698-42e9-a40b-9cf609c8ac45',
#  877: '74f071ad-a1e1-40e7-9335-e9f8d7b03796',
#  878: '6ee493d3-bf69-49a6-a5bb-0a664871a455',
#  879: '83b89ad0-427f-41be-9f2b-1ff2a51a2c4c',
#  880: 'f20cf69b-3420-43ef-a720-c9a1bdb04c19',
#  881: '2c0958c7-60e6-496e-ad2f-e37cea30ffdc',
#  882: 'a9896c63-6c6e-48cd-999a-50faff9ffba1',
#  883: '2913cb2e-5975-4349-988c-9b0728238e2d',
#  884: 'bda8b2ce-811c-448e-99a1-39970e6e5218',
#  885: 'dec42b84-65c7-492e-b0e8-c2734c8ea441',
#  886: '2bf94ba5-ee86-4dc9-b901-7847af1e71dc',
#  887: 'e83fe0c0-6287-451c-af8c-b98073c52a5c',
#  888: '08a1c3bf-88a9-45b7-8057-6a93f6cc28ca',
#  889: '9c5d7099-f939-4b04-8462-3f238ad2991f',
#  890: 'b20e45f2-1aa4-40e4-9138-40b063827027',
#  891: '773a9cb4-7da5-4e2b-97a5-cb1b06b1d57a',
#  892: '230d6c63-d50d-4268-b392-97fed6296c61',
#  893: '4c7dce2b-adad-4dbe-af78-38345d0fa867',
#  894: '10cdc4c7-8fd3-4ec2-958d-e735381944b9',
#  895: 'ac011b78-b906-422e-a1fd-16b984596caa',
#  896: '5e626ceb-c74e-45c4-a6e3-87698a61b921',
#  897: '34d0b760-0de8-471f-a65f-a9e69356ba05',
#  898: 'c436c5ae-ff2c-4d00-a277-8f6dc7fbe82a',
#  899: '06e730e8-906b-4051-b07b-527f3dde79d0',
#  900: '9057f894-99f5-4318-bc77-26e13c29b31f',
#  901: 'f98f686e-a3d6-40fa-a4f3-2c3f0c1a27be',
#  902: '7ae976e7-9361-45c0-b27e-d1ac1f6cf81d',
#  903: '0bb84077-0b48-42c7-b515-44c7ed58d82b',
#  904: '96d69d3c-e175-4484-9efa-7624808c9610',
#  905: '1f6594f0-2f37-417c-bbcd-aa3d12624e0b',
#  906: '9012f469-8fb6-4418-9175-7149bc4b20f7',
#  907: '9e724c71-2c7d-4929-8bfe-8f8a67e2ed61',
#  908: '6024b689-bbd4-468a-b810-36d1cfe7bd54',
#  909: 'ae3a8b5a-82f5-46c0-b2f3-97f3cb801492',
#  910: '395089e5-eb65-4381-bd6a-41108ce6a45b',
#  911: '0e809e16-37af-4508-84f4-77975f778c5a',
#  912: '1f19d38e-98f0-45ab-9006-88ead272b5de',
#  913: '65ae8185-6af9-4092-b401-29e6b15d9b7d',
#  914: 'f59ff74c-2e01-4420-91a9-15a4fcd44486',
#  915: '5239696d-2bbb-4532-b5d5-aba24294b616',
#  916: 'c7760846-ca78-48be-bd91-3977115a61ca',
#  917: '9075d37e-edea-46b5-8f5b-f20389c81708',
#  918: '7476dac8-2243-46c6-90d4-cb74e5cd8444',
#  919: 'f050ecac-85e0-4cc2-b0d4-74b792d3bb4c',
#  920: '555fc587-1981-46a1-8b56-2d857d72b030',
#  921: '68c5d518-0622-4780-a27a-7acab062dd76',
#  922: 'cb267200-a208-4a95-b094-6db1335d0904',
#  923: '7ce4808f-9fcc-4d6d-8d0f-81c881662fb3',
#  924: 'd98fdd04-c63a-4d0b-8900-cb88e838d4e2',
#  925: '4aededb3-34ac-41bc-b444-a536dc482cfc',
#  926: '7ded52af-b3a9-4b4f-9b1a-25d11e919703',
#  927: '12ffe4bd-90bd-4c56-9695-f3664f50ee54',
#  928: '51b72a48-3d9a-4bb9-8f4c-3866bb6709e9',
#  929: '006e9f00-ea59-4ef9-8ee0-5671011c70d9',
#  930: 'c2cc456e-c9e3-4752-ae4f-27d39af4eb97',
#  931: '1248a626-1d88-4dd5-94fb-cce60060ad7b',
#  932: '8161bb97-1530-47e0-b19c-72c0e87b6ec6',
#  933: '00c1eff8-29b8-4971-ac1b-8b74995a876d',
#  934: 'fa04c20f-a88e-403a-97c9-cc021849aa25',
#  935: '89a0259a-2558-48b0-a298-14e7013c5982',
#  936: '4fa58e54-5f22-4970-a110-de4c00115cbf',
#  937: 'c26400df-1900-4fa4-9119-1d116468eb75',
#  938: '1b44fbf9-c434-41e7-8312-9b5b4aa7087c',
#  939: '9110d6b6-b002-42e5-9d30-aec7d6c092b8',
#  940: 'aa66e25f-05b8-424a-bae1-f8140a17162b',
#  941: '04626121-f4c2-4037-aaf6-c92cdf7654d3',
#  942: 'e3d516ca-cfaf-4852-af41-b8bf88d980c3',
#  943: '7b3ec4ba-0f42-4604-9be3-64eeeff40901',
#  944: '5c0fcc15-739f-4533-a82f-ecdd3caa35b7',
#  945: '6dce0630-3173-4a37-ae32-a25536f528d3',
#  946: 'c5144679-96ca-47b6-864f-4cfa0a1e5352',
#  947: '461fd33d-3d69-46b3-84ec-9a32249117ca',
#  948: '0ec29b68-2b5c-40d5-bed2-c414f1d27b45',
#  949: 'cd656574-133c-4071-b4ad-3fa3ff04c828',
#  950: '0c9819b6-3b1f-44af-b97d-40fe2873e5c3',
#  951: '147f5a83-2729-4337-a801-33a60204f2ec',
#  952: 'd2f95230-e0bf-499b-b5d6-1fa512dcaf22',
#  953: '35a23c78-64ef-4b55-813a-f99c06a8c711',
#  954: '349996ee-d3bc-4e0a-8656-6e65a679cd2b',
#  955: '753f5648-4a67-488d-bf5c-4f854e429ecb',
#  956: 'ca8be25d-6405-4200-908d-efdfbd2510c5',
#  957: 'd72d4fa5-fbd0-490d-8000-4e77c1eed363',
#  958: '9db8010d-5274-494e-aa11-7f216bdb7942',
#  959: '823789c6-4104-4c85-876d-a72790035a5b',
#  960: 'd560e414-84f6-4d77-ab0e-746a1c1b25a0',
#  961: 'ef9650d6-3532-4583-a531-8834f4605f45',
#  962: '6ce8c1c8-b98b-4d3c-8544-875d46a0394b',
#  963: 'cd0931b1-cdfe-4b6f-8ba0-42989bd71a17',
#  964: '5080067c-20b5-42ab-b0eb-1c9d7ff1b0e9',
#  965: 'dbc3827f-ef2d-4d91-af1d-821f898ca041',
#  966: 'fa179c9c-9b3b-4175-b9af-cf89c37cd626',
#  967: 'a46598e2-df7b-40dc-9be6-5d1d3cf151ef',
#  968: '728962b4-eda6-428c-a0e8-82fd3d6e079b',
#  969: '0ffd4e9f-4954-4f4a-a08f-3e314b082015',
#  970: '6429ec82-34e0-4a73-a5fb-86729e3eba85',
#  971: 'e5045f59-5f7d-4def-9cb0-017d69772ac9',
#  972: 'cf4df1b0-2bd0-41ed-8b95-6b466f8fbf6e',
#  973: 'f4667d08-9292-4fcc-83c7-cbc55dc09584',
#  974: '5339c232-929a-410b-861e-26b0012f2ae3',
#  975: '460012b4-ed7c-4e01-887c-c65d4544706d',
#  976: '398d8226-376b-46a8-9c0c-fcd95cbc7d21',
#  977: '3e577468-4e44-45ba-87cb-bafe64482856',
#  978: '9c978798-bd25-461e-8ce4-f125e46e8131',
#  979: '4e836839-4367-4134-b69c-0cd19d37ad62',
#  980: '4dbf44a2-fcd9-488c-be16-0e92a0d6f881',
#  981: '3afb39e7-4fea-44fd-94da-4d7618882110',
#  982: '2f247fc3-6a30-49a8-aeb2-76b659fe4f31',
#  983: '3797ed10-eaf2-4d0a-ba7f-be6ca4c47234',
#  984: '9d2bcbb1-a29f-44af-8def-5bf7bcd10f33',
#  985: '9f2d8466-82f3-4d06-bedf-52c72f95c4ae',
#  986: 'a0d9a208-e569-4f21-92a7-1b558ffc0549',
#  987: '4a8a966a-6b48-4a6d-88a4-51941b212dbd',
#  988: '97aa1e4e-487b-4fef-9307-7c6373ee56db',
#  989: 'a435035e-bb43-4cc7-99ba-f4322a6d5d0b',
#  990: 'c0dda829-e1b4-4541-bf8a-aaf15f2fb287',
#  991: '85ca37be-5530-480c-b67d-7ae6383b15fc',
#  992: '32b6d1e7-7720-44cd-943a-24bac66d60bd',
#  993: '5535e589-1c53-41db-aa43-2f8ecde6892b',
#  994: '936e76b5-510b-442d-9ef0-e30edf0c36a3',
#  995: '485d02a3-9c1f-4114-912e-e61e867e3877',
#  996: '394c9d13-dbf1-4ef2-8c92-69ca9f360734',
#  997: '070cb6b8-7047-48ef-856b-33817c3216db',
#  998: '3581595b-a5ea-4bc3-80cf-03346e7ad75a',
#  999: '8bd53404-0f7d-4a36-afa0-c730a25a070b',
#  ...}

# %% [markdown]
# ## 4. Retriver

# %%
# retriever = vector_store.as_retriever(
#     search_type="mmr",
#     search_kwargs={"k": 2, "fetch_k": 10, "lambda_mult": 0.6}
# )

# %% [markdown]
# ### 압축

# %%
from langchain_openai import OpenAI

# model="gpt-4o-mini"를 사용하면 오류 발생
llm = OpenAI(temperature=0)

# %%
from langchain.retrievers.document_compressors import LLMChainExtractor

compressor = LLMChainExtractor.from_llm(llm)

# %% [markdown]
# ### Retrievers

# %%
from langchain.retrievers import ContextualCompressionRetriever

compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=vector_store.as_retriever(
        search_type="mmr",
        search_kwargs={"k": 2, "fetch_k": 10, "lambda_mult": 0.6}
    )
)

# %%
# 관련 문서를 검색합니다.
docs = compression_retriever.invoke("langchain.text_splitter Python")

# 관련 문서를 검색
for doc in docs:
    print(doc.page_content)
    print("=========================================================")
# Out:
# LangChain 0.0.20, Python 3.9, LangChain 0.0.224
# =========================================================
# from itertools import chain
# =========================================================

# %% [markdown]
# ## Retriever 변환

# %%
from langchain.tools.retriever import create_retriever_tool

# %%
# retriever_tool = create_retriever_tool(
#     compression_retriever,
#     name="vector_search",  # 도구의 이름을 입력합니다.
#     description="use this tool to search information from the vector document",  # 도구에 대한 설명을 자세히 기입해야 합니다!!
# )

# %%
# tools = [retriever_tool]

# %% [markdown]
# ## Agent

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0)

from langchain_core.prompts import PromptTemplate

# 프롬프트 템플릿을 정의합니다.(5개의 질문을 생성하도록 프롬프트를 작성하였습니다)
prompt = PromptTemplate.from_template(
    """
    You are an AI language model assistant.
    Your task is to generate five different versions of the given user question to retrieve relevant documents from a vector database.
    By generating multiple perspectives on the user question, your goal is to help the user overcome some of the limitations of the distance-based similarity search.
    Your response should be a list of values separated by new lines, eg: `foo\nbar\nbaz\n`

    #ORIGINAL QUESTION:
    {question}

    #Answer in Korean:
    """
)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# LLMChain을 생성합니다.
custom_multiquery_chain = (
    {"question": RunnablePassthrough()} | prompt | llm | StrOutputParser()
)

# %%
# 질문을 정의합니다.
question = "langchain.text_splitter Python에 대해 알려줘."

# 체인을 실행하여 생성된 다중 쿼리를 확인합니다.
multi_queries = custom_multiquery_chain.invoke(question)

# 결과를 확인합니다.(5개 질문 생성)
multi_queries
# Out:
# 'Langchain의 텍스트 분할기 기능에 대해 설명해줘.\nLangchain에서 Python을 사용한 텍스트 분할 방법은?\nPython으로 Langchain의 텍스트 분할기를 사용하는 방법은 무엇인가요?\nLangchain의 텍스트 분할기를 Python으로 구현하는 방법에 대해 알려주세요.\nPython에서 Langchain의 텍스트 분할 기능을 활용하는 방법은?'

# %%
from langchain.retrievers.multi_query import MultiQueryRetriever

# %%
multiquery_retriever = MultiQueryRetriever.from_llm(
    llm=custom_multiquery_chain, retriever=compression_retriever
)

# %%
# 결과
relevant_docs = multiquery_retriever.invoke(question)

# 검색된 고유한 문서의 개수를 반환합니다.
# Out:
# ===============
# 검색된 문서 개수: 3
# ===============
# Python

# %%
print(
    f"===============\n검색된 문서 개수: {len(relevant_docs)}",
    end="\n===============\n",
)
# 검색된 문서의 내용을 출력합니다.
print(relevant_docs)
# Out:
# ===============
# 검색된 문서 개수: 3
# ===============
# [Document(metadata={'source': 'data/qna.csv', 'row': 126}, page_content='Python'), Document(metadata={'source': 'data/qna.csv', 'row': 1}, page_content='LangChain 0.0.20, Python 3.9, LangChain 0.0.224'), Document(metadata={'source': 'data/qna.csv', 'row': 1242}, page_content='<p>Works out-of-the-box with any Python version 3.7-3.11.</p>\n<p>Fully multi-platform, and uses the OS support to load the dynamic libraries, thus ensuring full compatibility.</p>')]

# %%
display_message_tree(relevant_docs)
# Out:
# root[0]:
#     root[0]: page_content='Python' metadata={'source': 'data/qna.csv', 'row': 126}
# root[1]:
#     root[1]: page_content='LangChain 0.0.20, Python 3.9, LangChain 0.0.224' metadata={'source': 'data/qna.csv', 'row': 1}
# root[2]:
#     root[2]: page_content='<p>Works out-of-the-box with any Python version 3.7-3.11.</p>
# <p>Fully multi-platform, and uses the OS support to load the dynamic libraries, thus ensuring full compatibility.</p>' metadata={'source': 'data/qna.csv', 'row': 1242}
